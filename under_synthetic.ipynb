# %% [markdown]
# # Under-Representation Bias (w/ Synthetic Data)

# %% [markdown]
# This notebook recreates the finding that Equalized Odds constrained model can recover from under-representation bias.

# %% [markdown]
# ### Setup
#
# Please run the code block below to install the necessary packages (if needed).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

from sklearn.base import clone

from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, roc_curve, auc
from collections import Counter

import fairlearn
from fairlearn.metrics import *
from fairlearn.reductions import *
import aif360

import copy, random

from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Synthetic Dataset Generation

# %% [markdown]
# ## Parameters (User Input)

# %%
'''

r is the proportion of training examples in the minority group, 

which means 1-r is proportion of examples in the majority group

eta is the probability of flipping the label

n is the number of training examples

beta is the probability of keeping a positively labeled example
from the minority class

NOTE: results can be replicated if and only if the following condition holds:

(1-r)(1-2*eta) + r((1-eta)*beta - eta) > 0

'''
def get_params(r = 1/3, eta = 1/4, n = 2000, beta = 0.5):
    return r, eta, n, beta

r, eta, n, beta = get_params(r = 1/3, eta = 0, n = 30000)

# %%
# check if above constraint holds
def check_constraints(r, eta, beta):
    first = (1-r)*(1-2*eta)
    second = r * ((1-eta)*beta - eta)
    res = first + second
    print("constraint: ", res)
    print("yes!", r, eta, beta) if res > 0 else print("no", r, eta, beta)
    
bias_amts = np.divide(list(range(10, -1, -1)),10)

for beta in bias_amts:
    check_constraints(r=0.2, eta=0.4, beta=beta)
# Out:
# constraint:  0.19999999999999996
# yes! 0.2 0.4 1.0
# constraint:  0.18799999999999997
# yes! 0.2 0.4 0.9
# constraint:  0.17599999999999996
# yes! 0.2 0.4 0.8
# constraint:  0.16399999999999998
# yes! 0.2 0.4 0.7
# constraint:  0.15199999999999997
# yes! 0.2 0.4 0.6
# constraint:  0.13999999999999996
# yes! 0.2 0.4 0.5
# constraint:  0.12799999999999997
# yes! 0.2 0.4 0.4
# constraint:  0.11599999999999996
# yes! 0.2 0.4 0.3
# constraint:  0.10399999999999997
# yes! 0.2 0.4 0.2
# constraint:  0.09199999999999997
# yes! 0.2 0.4 0.1
# constraint:  0.07999999999999996
# yes! 0.2 0.4 0.0

# %% [markdown]
# ## True Label Generation

# %%
# create minority and majority groups
def get_cat_features(n, r):
    num_minority = int(r * n)
    num_majority = n - num_minority
    
    minority = np.zeros((num_minority, 1))
    majority = np.ones((num_majority, 1))
    
    cat_features = np.vstack((minority, majority))
    #np.random.shuffle(cat_features) # this is what causes us to not recover coeffs
    
    return cat_features

# %%
# return labels from Bayes Optimal Classifier
def get_bayes_optimal_labels(features, effect_param, threshold = 0.5):
    outcome_continuous = 1/(1+np.exp(-np.matmul(features, effect_param)))
    #return outcome_continuous, np.random.binomial(1,outcome_continuous) # bernoulli to simulate LR's probabilistic nature
    return outcome_continuous, np.where(outcome_continuous < threshold, 0, 1)

# flip labels with probability eta
# def flip_labels(df_synthetic, eta):
#     labels = df_synthetic['outcome']
#     #print('Before:', df_synthetic['outcome'].value_counts())
#     num_flipped = 0
#     for i in range(len(labels)):
#         if random.uniform(0,1) <= eta:
#             labels[i] = 1 if labels[i] == 0 else 0
#             num_flipped += 1
#     df_synthetic['outcome'] = labels
#     #print('After:', df_synthetic['outcome'].value_counts())
#     #print('Num Flipped: ', num_flipped, "\tRate: ", num_flipped / len(df_synthetic))
#     return df_synthetic

def flip_labels(df_synthetic, eta):
    labels = list(df_synthetic['outcome'].values)
    #print('Before:', df_synthetic['outcome'].value_counts())
    num_flipped = 0
    for i in range(len(labels)):
        if random.uniform(0,1) <= eta:
            labels[i] = 1 if labels[i] == 0 else 0
            num_flipped += 1
    df_synthetic['outcome_flipped'] = labels
    df_synthetic['outcome'] = labels
    #print('After:', df_synthetic['outcome'].value_counts())
    #print('Num Flipped: ', num_flipped, "\tRate: ", num_flipped / len(df_synthetic))
    return df_synthetic

# use this function to inject eta_maj into both majority and negatively labeled minority samples
def flip_labels2(df_majority, eta_maj, df_minority, eta_min, inter = True):
    labels_maj = list(df_majority['outcome'].values)
    labels_min = list(df_minority['outcome'].values)
    
    num_flipped_maj = 0
    for i in range(len(labels_maj)):
        if random.uniform(0,1) <= eta_maj:
            labels_maj[i] = 1 if labels_maj[i] == 0 else 0
            num_flipped_maj += 1
    df_majority['outcome_flipped'] = labels_maj
    print('Num Flipped Maj: ', num_flipped_maj, "\tRate: ", num_flipped_maj / len(df_majority))
    if not inter: df_minority['outcome_flipped'] = labels_min
    
    if inter:
    
        #df_majority['diff'] = abs(df_majority['outcome'] - df_majority['outcome_flipped'])
        #print(df_minority.groupby('outcome')['diff'].value_counts(normalize=True))

        neg = len(df_minority[df_minority['outcome'] == 0])

        num_flipped_min = 0
        for i in range(len(labels_min)):
            if random.uniform(0,1) <= eta_maj and labels_min[i] == 0:
                labels_min[i] = 1
                num_flipped_min += 1

        df_minority['outcome_flipped'] = labels_min
        #df_minority['diff'] = abs(df_minority['outcome'] - df_minority['outcome_flipped'])
        #print("minority", df_minority.groupby('outcome')['diff'].value_counts(normalize=True))

        print('Num Flipped Min Neg: ', num_flipped_min, "\tRate: ", num_flipped_min / neg)

    df_concat = pd.concat([df_majority, df_minority])
    #print(df_majority.shape, df_minority.shape)
    #df_concat = pd.DataFrame(np.vstack([df_majority, df_minority]))
    #df_concat.columns = ['num1','num2','num3','cat','outcome','outcome_flipped', 'diff']
    
    #print("concat", df_concat.groupby(['cat','outcome'])['diff'].value_counts(normalize=True))
    return df_concat.sample(frac=1, random_state = 42) # permute data

# %%
pd.options.mode.chained_assignment = None  # default='warn'
'''

create synthetic data with:
    3 numerical features (Gaussian), 1 categorical (sensitive attribute) 
    logistic outcome model s.t. outcome = Indicator[logit(effect_param*features) >= 0.5]
    
create minority/majority groups according to r param

simulate Bayes Optimal Classifiers for minority and majority

flip labels according to eta param

ensure equal base rates (proportion of positive examples) across both groups

is_exploration is for group-dependent label noise

'''

def true_label_generation(r, eta, n, maj_means = [0,0,0], is_exploration = False, inter = True):

    ''' 
    delete this variable to allow user to control percentage of positively labeled examples
    eg: let outcome_continuous >= 0.2 implies 80% positively labeled samples
    '''
    # causal effect params
    maj_params = [-0.7, 0.5, 1.5]
    effect_param_min = [0.5, -0.2, 0.1]
    #effect_param_maj = [i + np.random.uniform(low = -1, high = 1) for i in maj_params]
    effect_param_maj = maj_params
    
    num_min = int(n*r)
    num_maj = n - num_min

    # required: len(cat_probabilities) = n_cat_features
    n_cat_features = 2
    cat_probabilities = [0.5, 0.5] 

    # numerical feature params
    means = [0, 0, 0]
    cov_matrix = [[1, 0, 0], [0, 1, 0], [0, 0, 1]]

    # features
    cat_features = get_cat_features(r=r, n=n)
    
    num_features_min = np.random.multivariate_normal(means, cov_matrix, num_min)
    #num_features_min = np.random.normal(0, 1, num_min)
    num_features_maj = np.random.multivariate_normal(maj_means, cov_matrix, num_maj)
    # num_features_maj = np.array([i + np.random.uniform(low = -15, high = 10) for i in num_features_maj])
    #num_features_min = np.random.normal(0, 1, num_min)

    num_features = np.concatenate((num_features_min, num_features_maj))

    # outcomes
    outcome_continuous_min, outcome_binary_min = get_bayes_optimal_labels(features=num_features_min, effect_param=effect_param_min, threshold = 0.5)
    #outcome_binary_min = np.where(np.matmul(num_features_min, effect_param_min) > 0.5, 1, 0)
    outcome_continuous_maj, outcome_binary_maj = get_bayes_optimal_labels(features=num_features_maj, effect_param=effect_param_maj, threshold = 0.5)
    #outcome_binary_maj = np.where(np.matmul(num_features_maj, effect_param_maj) > 0.5, 1, 0)
    
    outcome = np.hstack((outcome_binary_min,outcome_binary_maj)).reshape(n,1)
    outcome_continuous = np.hstack((outcome_continuous_min,outcome_continuous_maj)).reshape(n,1)
    temp_data = np.hstack((num_features,cat_features, outcome, outcome_continuous))
    #print(outcome_continuous)
    #print(np.where(outcome_continuous < 0.5, 0, 1))
    np.random.shuffle(temp_data) # randomly shuffle the data
    
    df_synthetic = pd.DataFrame(temp_data)
    df_synthetic.columns = ['num1','num2','num3','cat','outcome','outcome_cont']
    
    outcome_continuous = df_synthetic.outcome_cont
    df_synthetic = df_synthetic[['num1','num2','num3','cat','outcome']]
    
    df_majority = df_synthetic[df_synthetic['cat'] == 1]
    df_minority = df_synthetic[df_synthetic['cat'] == 0]
    
    #print('% Positive Majority: ', df_majority['outcome'].value_counts()[1] / len(df_majority))
    #print('\n% Positive Minority: ', df_minority['outcome'].value_counts()[1] / len(df_minority))
    print('Diff: ', df_majority['outcome'].value_counts()[1] / len(df_majority)- df_minority['outcome'].value_counts()[1] / len(df_minority))
    #print('\nTotal: ', df_majority['outcome'].value_counts())
    
    if inter:
        if not is_exploration: 
            df_synthetic = flip_labels(df_synthetic, eta)
        else:
            df_synthetic = flip_labels2(df_majority, 0.4, df_minority, 0) # group dependent label noise
    else:
        df_synthetic = flip_labels2(df_majority, 0.4, df_minority, 0, inter = False) # group dependent label noise

    return outcome_continuous, df_synthetic 

outcome_continuous, df_synthetic = true_label_generation(r=r, eta=eta, n=2*n, maj_means = [0,0,0], is_exploration=True, inter=False)
# Out:
# Diff:  -0.009000000000000008
# Num Flipped Maj:  16007 	Rate:  0.400175

# %%
# df_synthetic['diff'] = abs(df_synthetic['outcome'] - df_synthetic['outcome_flipped'])
# df_synthetic.groupby(['cat','outcome'])['diff'].value_counts(normalize=True)

def check_groups(df):
    df = df.copy()
    df['diff'] = abs(df['outcome'] - df['outcome_flipped'])
    print(df.groupby(['cat','outcome'])['diff'].value_counts(normalize=True))

check_groups(df_synthetic)
# Out:
# cat  outcome  diff
# 0.0  0.0      0.0     1.000000
#      1.0      0.0     1.000000
# 1.0  0.0      0.0     0.598723
#               1.0     0.401277
#      1.0      0.0     0.600932
#               1.0     0.399068
# Name: diff, dtype: float64

# %% [markdown]
# # Preparation

# %% [markdown]
# ### Data Preprocessing

# %%
# split into train and test
df_train = df_synthetic.loc[range(0,int(n/2)), :]
# if original dataset has odd number of samples, remove 1 sample to be even
if (n % 2 == 1):
    df_test = df_synthetic.loc[range(int(n/2)+1, n), :]
else:
    df_test = df_synthetic.loc[range(int(n/2), n), :]

df_fidel = df_synthetic.loc[range(n, len(df_synthetic)),:]
outcome_cts = outcome_continuous[n:len(df_synthetic)]
    
df_test_maj = df_test[df_test['cat'] == 1]
df_test_min = df_test[df_test['cat'] == 0]

# format data
X_true = df_test.iloc[:, :-2].values
y_true = df_test.iloc[:, -1].values

X_true_maj = df_test_maj.iloc[:, :-2].values
y_true_maj = df_test_maj.iloc[:, -1].values
X_true_min = df_test_min.iloc[:, :-2].values
y_true_min = df_test_min.iloc[:, -1].values

sens_attrs_true = [df_test['cat']]

# %% [markdown]
# # Bias Injection

# %%
# measurement bias
def inject_noise_num(df, feature, eps = 1):
    for i in range(len(df[feature])):
        df[feature].iloc[i] += np.random.normal(0, 1) * eps # standard normal

    return df

# %%
from numpy import percentile
def under_sample(df_minority_positive, beta):
    X_min = df_minority_positive.iloc[:, :].values
    
    # keep each example with probability beta
    num_dropped = 0
    for i in range(len(X_min)):
        if random.uniform(0,1) > beta:
            X_min = np.delete(X_min, 0, axis=0)
            num_dropped += 1
    #print("Total Deleted: ", num_dropped, "\t % Deleted: ", num_dropped / len(df_minority_positive))
    df_minority_positive = pd.DataFrame(pd.DataFrame(X_min))
    df_minority_positive.columns = ['num1','num2','num3','cat','outcome', 'outcome_flipped']
    return df_minority_positive


def get_biased_data(df_train, beta):
    df_majority = df_train[df_train['cat'] == 1]
    df_minority = df_train[df_train['cat'] == 0]
    
    # unfavored group with negative label
    df_minority_negative = df_minority[df_minority['outcome'] == 0.0]

    # unfavored group with positive label (preferred)
    df_minority_positive = df_minority[df_minority['outcome'] == 1.0]
    
    # data frame without positively labeled examples from minority class
    df_total = pd.concat([df_majority, df_minority_negative])
    
    # under-sampling process
    df_undersampled = under_sample(df_minority_positive, beta)

    # combine undersampled and original favored class to create dataset
    df_concat = pd.concat([df_total,df_undersampled])
    
    return df_concat.sample(frac=1) # permute data


'''

# representation bias, under-sampling entire minority
def get_biased_data(df_train, beta):
    df_majority = df_train[df_train['cat'] == 1]
    df_minority = df_train[df_train['cat'] == 0]
    
    # under-sampling process
    df_undersampled = under_sample(df_minority, beta)

    # combine undersampled and original favored class to create dataset
    df_concat = pd.concat([df_majority,df_undersampled])
    
    return df_concat.sample(frac=1) # permute data
'''

def get_summary_num(df, feature):
    res = dict()
    res['attribute'] = feature

    data_min, data_max = df[feature].min(), df[feature].max()
    res['min'] = data_min
    res['max'] = data_max

    quartiles = percentile(df[feature], [25,50,75])
    res['1st Quartile'] = quartiles[0]
    res['2nd Quartile'] = quartiles[1]
    res['3rd Quartile'] = quartiles[2]

    return res

#print(len(df_train[(df_train['cat'] == 0) & (df_train['outcome'] == 1)]))
print(get_summary_num(df_train, 'num1'))
df_concat = get_biased_data(df_train, 0.5)
print(get_summary_num(df_concat, 'num1'))
#print(len(df_concat[(df_concat['cat'] == 0) & (df_concat['outcome'] == 1)]))

# for fairness measures later
df_sens = df_concat['cat']

# format data
X_bias = df_concat.iloc[:, :-2].values
y_bias = df_concat.iloc[:, -1].values
# Out:
# {'attribute': 'num1', 'min': -3.8163161006143285, 'max': 3.7695896300794987, '1st Quartile': -0.6737173384527013, '2nd Quartile': 1.6201592560062856e-05, '3rd Quartile': 0.6694817360867982}
# {'attribute': 'num1', 'min': -3.8163161006143285, 'max': 3.7695896300794987, '1st Quartile': -0.7383726834195298, '2nd Quartile': -0.07904273238259804, '3rd Quartile': 0.5993013656487575}

# %%
''' Nil-Jana's Suggestions '''

def transform(df, is_test = False, is_train = False):

    sens_feat = df['cat'].values
    outcome = df['outcome'].values
    outcome_flipped = df['outcome_flipped'].values
    num_feats = df.iloc[:, :-3].values

    trans_feats = [] # x1a - x3a
    other_feats = [] # x1(1-a) - x3(1-a)
    # -2 for sensitive feature and label
    for i in range(len(df.columns) - 3):
        num_feat = df.iloc[:, i].values
        num_feat_transf = np.multiply(num_feat, sens_feat)
        trans_feats += [num_feat_transf.reshape((len(df),))]
        
        num_feat_other = df.iloc[:, i].values
        num_feat_other_transf = np.multiply(num_feat, (1-sens_feat))
        other_feats += [num_feat_other_transf.reshape((len(df),))]


    temp_data = np.hstack((other_feats[0].reshape((len(df),1)), other_feats[1].reshape((len(df),1)), other_feats[2].reshape((len(df),1)),
                           trans_feats[0].reshape((len(df),1)), trans_feats[1].reshape((len(df),1)), trans_feats[2].reshape((len(df),1)),
                           outcome.reshape((len(df),1)), outcome_flipped.reshape((len(df),1))))

    df_transf = pd.DataFrame(temp_data)
    df_transf.columns = ['num1*(1-a)','num2*(1-a)','num3*(1-a)', 'num1*a','num2*a','num3*a','outcome', 'outcome_flipped']

    # for fairness measures later
    df_sens = df['cat']
    maj_list = list(df[df['cat'] == 1].index)
    min_list = list(df[df['cat'] == 0].index)
    
    for i in range(len(maj_list)):
        if is_train: maj_list[i] = maj_list[i]
        else: maj_list[i] = maj_list[i] - len(df)
        
    for i in range(len(min_list)):
        if is_train:
            min_list[i] = min_list[i]
        else: min_list[i] = min_list[i] - len(df)

    # format data
    X_bias = df_transf.iloc[:, :-2].values
    y_bias = df_transf.iloc[:, -1].values
    
    if not is_test:
        return X_bias, y_bias, df_sens
    else:
        return df_transf, maj_list, min_list

df_transf, _, _ = transform(df_test, True)

# %% [markdown]
# # Evaluation

# %%
def under(df, beta):
    X_min = df.iloc[:, :].values
    
    # keep each example with probability beta
    num_dropped = 0
    for i in range(len(X_min)):
        if random.uniform(0,1) > beta:
            X_min = np.delete(X_min, 0, axis=0)
            num_dropped += 1
    print("Total Deleted: ", num_dropped, "\t % Deleted: ", num_dropped / len(df))
    df = pd.DataFrame(pd.DataFrame(X_min))
    df.columns = ['num1','num2','num3','cat','outcome', 'outcome_flipped']
    return df

# %%
def tradeoff_visualization_error(r, n, apply_fairness = True, verbose = False, num_iters = 10):
    
    total_fidel_maj = []
    total_fidel_min = []
    total_fidel = []
    
    total_disp_bias_train = []
    total_disp_bo_train = []
    total_disp_mitigated_train = []
    
    total_disp_bias_test = []
    total_disp_bo_test = []
    total_disp_mitigated_test = []
    
    total_acc_bias_train = []
    total_acc_bo_train = []
    total_acc_mitigated_train = []
    
    total_acc_bias_test = []
    total_acc_bo_test = []
    total_acc_mitigated_test = []
    
    for i in range(num_iters):
    
        # 1 to 0 in increments of 0.1
        bias_amts = np.divide(list(range(10,-1,-1)),10)

        test_maj = []
        test_min = []
        total = []
        
        disp_bias_train = []
        disp_bo_train = []
        disp_mitigated_train = []
        
        disp_bias_test = []
        disp_bo_test = []
        disp_mitigated_test = []
        
        acc_bias_train = []
        acc_bo_train = []
        acc_mitigated_train = []
        
        acc_bias_test = []
        acc_bo_test = []
        acc_mitigated_test = []
        
        count = 0
        outcome_continuous, df_synthetic = true_label_generation(r=r, eta=eta, n=2*n, is_exploration=False)
        
        threshold = 0.5
        exact_bo_labels = np.where(outcome_continuous < threshold, 0, 1)
        exact_bo_labels_train = np.array(exact_bo_labels[range(0,n)])
        exact_bo_labels_test = np.array(exact_bo_labels[range(n,len(df_synthetic))])
        
        # split into train and test
        df_train = df_synthetic.loc[range(0,n), :]
        #check_groups(df_train)
        
        df_train_transf, maj_list, min_list = transform(df_train, True, True)
        
        df_test = df_synthetic.loc[range(n, len(df_synthetic)),:]
        #check_groups(df_test)
        df_test_transf, maj_list, min_list = transform(df_test, True, False)
        
        df_test_maj = df_test_transf.loc[maj_list]
        df_test_min = df_test_transf.loc[min_list]

        # format training data
        X_true = df_train_transf.iloc[:, :-2].values
        y_true = df_train_transf.iloc[:, -1].values
        
        # format test data
        X_test = df_test_transf.iloc[:, :-2].values
        X_test_maj = df_test_maj.iloc[:, :-2].values
        X_test_min = df_test_min.iloc[:, :-2].values
        y_test = df_test_transf.iloc[:, -1].values
        y_test_maj = df_test_maj.iloc[:, -1].values
        y_test_min = df_test_min.iloc[:, -1].values
        
        sens_attr_test = df_test['cat']
        
        for beta in bias_amts:
            
            if i == 0: print("Beta: ", beta, '\n')

            df_train_copy = df_train.copy()

            df_majority = df_train_copy[df_train_copy['cat'] == 1]
            df_minority = df_train_copy[df_train_copy['cat'] == 0]
            
            # NOTE: we can use outcome_flipped in both lines below but
            #.      we set outcome = outcome_flipped in flip_labels

            # unfavored group with negative label
            df_minority_negative = df_minority[df_minority['outcome'] == 0.0]

            # unfavored group with positive label (preferred)
            df_minority_positive = df_minority[df_minority['outcome'] == 1.0]

            # data frame without positively labeled examples from minority class
            df_total = pd.concat([df_majority, df_minority_negative])

            # under-sampling process
            df_undersampled = under(df_minority_positive, beta)

            # combine undersampled and original favored class to create dataset
            df_concat = pd.concat([df_total,df_undersampled]).sample(frac=1, random_state = 42)
            #check_groups(df_concat)

            # format data
            X_bias_true, y_bias_true, df_sens = transform(df_concat)
            
            # model trained on biased data
            classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none')
            classifier_bias = classifier.fit(X_bias_true, y_bias_true)
            
            acc = accuracy_score(y_test,classifier_bias.predict(X_test))
            #print(f'Biased classifier:')
            #print(f'     Test accuracy = {acc}')
            acc_bias_test += [acc]
            acc_bias_train += [accuracy_score(y_bias_true, classifier_bias.predict(X_bias_true))]
            
            m = classifier_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            disparity = EqualizedOdds()
            disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            #print(f'     Train error = {error.gamma(classify)[0]}')
            #print(f'     Train disparity = {disparity.gamma(classify).max()}')
            disp_bias_train += [disparity.gamma(classify).max()]

            m = classifier_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            disparity = EqualizedOdds()
            disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            #print(f'     Test error = {error.gamma(classify)[0]}')
            #print(f'     Test disparity = {disparity.gamma(classify).max()}')
            disp_bias_test += [disparity.gamma(classify).max()]
            
            # Learned bayes optimal classifier
            classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none')
            classifier_b = classifier.fit(X_true, y_true)        
            print('COEF: ', classifier_b.coef_)
            print('INTERCEPT: ', classifier_b.intercept_)
            #classifier_b = clone(classifier).fit(X_true, y_true)
            acc = accuracy_score(y_test,classifier_b.predict(X_test))
            #print(f'Learned BO classifier:')
            #print(f'     Test accuracy = {acc}')
            acc_bo_test += [acc]
            acc_bo_train += [accuracy_score(y_bias_true, classifier_b.predict(X_bias_true))]
            
            m = classifier_b
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            disparity = EqualizedOdds()
            disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            #print(f'     Train error = {error.gamma(classify)[0]}')
            #print(f'     Train disparity = {disparity.gamma(classify).max()}')
            disp_bo_train += [disparity.gamma(classify).max()]

            m = classifier_b
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            disparity = EqualizedOdds()
            disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            #print(f'     Test error = {error.gamma(classify)[0]}')
            #print(f'     Test disparity = {disparity.gamma(classify).max()}')
            disp_bo_test += [disparity.gamma(classify).max()]
            
            
            # Exact BO optimal classifier
            #print(f'Exact BO classifier:')
            acc = accuracy_score(y_test,exact_bo_labels_test)
            #print(f'     Test accuracy = {acc}')
            acc = accuracy_score(y_true,exact_bo_labels_train)
            #print(f'     Train accuracy = {acc}')

            if apply_fairness:
                constraint = EqualizedOdds()
                classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none', fit_intercept = False, max_iter = 200)   

                classifier_mitigated_bias = GridSearch(estimator=classifier,
                                                       constraints=constraint,
                                                       selection_rule='tradeoff_optimization',
                                                       constraint_weight=0.5,
                                                       grid_size=10,
                                                       grid_limit=2.0,
                                                       grid_offset=None,
                                                       grid=None,
                                                       sample_weight_name='sample_weight')
                                                       
                classifier_mitigated_bias.fit(X_bias_true, y_bias_true, sensitive_features = df_sens)
                
                acc = accuracy_score(y_test,classifier_mitigated_bias.predict(X_test))
                #print(f'Mitigated bias classifier:')
                #print(f'     Test accuracy = {acc}')
                acc_mitigated_test += [acc]
                acc_mitigated_train += [accuracy_score(y_bias_true, classifier_mitigated_bias.predict(X_bias_true))]
                
                m = classifier_mitigated_bias
                def classify(X): return m.predict(X)
                error = ErrorRate()
                error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
                disparity = EqualizedOdds()
                disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
                #print(f'     Train error = {error.gamma(classify)[0]}')
                #print(f'     Train disparity = {disparity.gamma(classify).max()}')
                disp_mitigated_train += [disparity.gamma(classify).max()]
                
                m = classifier_mitigated_bias
                def classify(X): return m.predict(X)
                error = ErrorRate()
                error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
                disparity = EqualizedOdds()
                disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
                #print(f'     Test error = {error.gamma(classify)[0]}')
                #print(f'     Test disparity = {disparity.gamma(classify).max()}')
                disp_mitigated_test += [disparity.gamma(classify).max()]
                
                # Alternative fidelity of intervention model to no intervention model
                alt_fid_train = accuracy_score(classifier_mitigated_bias.predict(X_bias_true),classifier_bias.predict(X_bias_true))
                alt_fid_test = accuracy_score(classifier_mitigated_bias.predict(X_test),classifier_bias.predict(X_test))
                #print(f'Alternative fidelity of intervention model to no intervention model: train = {alt_fid_train}, test = {alt_fid_test}')
                

            else:
                classifier_mitigated_bias = clone(classifier_bias)
                classifier_mitigated_bias.fit(X_bias_true, y_bias_true)
                
                disp_mitigated_train += [0]
                disp_mitigated_test += [0]
                
                acc_mitigated_train += [0]
                acc_mitigated_test += [0]
                
                # NOTE: disparities are the same as for classifier_bias

                
            # Fidelity in this step
            fid = accuracy_score(classifier_mitigated_bias.predict(X_test),classifier_b.predict(X_test))
            #print(f'Test set fidelity of learned BO classifier and mitigated_bias_classifier: {fid}')
            fid = accuracy_score(classifier_mitigated_bias.predict(X_test),exact_bo_labels_test)
            #print(f'Test set fidelity of exact BO classifier and mitigated biased classifier: {fid}')
            fid = accuracy_score(classifier_bias.predict(X_test),classifier_b.predict(X_test))
            #print(f'Test set fidelity of learned BO classifier and biased classifier: {fid}')
            
            # fidelity check
            test_maj += [accuracy_score(classifier_mitigated_bias.predict(X_test_maj), classifier_b.predict(X_test_maj))]
            #print(test_maj)
            test_min += [accuracy_score(classifier_mitigated_bias.predict(X_test_min), classifier_b.predict(X_test_min))]
            #print(test_min)
            total += [accuracy_score(classifier_mitigated_bias.predict(X_test), classifier_b.predict(X_test))]
                
            if verbose:
                #print("Finished Iteration: ", count)
                count +=1
        
        #print(f'Fidelity test maj: {test_maj}')
        #print(f'Fidelity test min: {test_maj}')
        
        total_fidel_maj.append(test_maj)
        total_fidel_min.append(test_min)
        total_fidel.append(total)
        
        total_disp_bias_train.append(disp_bias_train)
        total_disp_bo_train.append(disp_bo_train)
        total_disp_mitigated_train.append(disp_mitigated_train)

        total_disp_bias_test.append(disp_bias_test)
        total_disp_bo_test.append(disp_bo_test)
        total_disp_mitigated_test.append(disp_mitigated_test)
        
        total_acc_bias_train.append(acc_bias_train)
        total_acc_bo_train.append(acc_bo_train)
        total_acc_mitigated_train.append(acc_mitigated_train)

        total_acc_bias_test.append(acc_bias_test)
        total_acc_bo_test.append(acc_bo_test)
        total_acc_mitigated_test.append(acc_mitigated_test)
        
        if verbose:
                print("Finished Total Iteration: ", i+1)
    
    mean_fidel_maj = np.mean(total_fidel_maj, axis = 0)
    mean_fidel_min = np.mean(total_fidel_min, axis = 0)
    mean_fidel = np.mean(total_fidel, axis = 0)
    
    mean_disp_bias_train = np.mean(total_disp_bias_train, axis = 0)
    mean_disp_bo_train = np.mean(total_disp_bo_train, axis = 0)
    mean_disp_mitigated_train = np.mean(total_disp_mitigated_train, axis = 0)
    
    mean_disp_bias_test = np.mean(total_disp_bias_test, axis = 0)
    mean_disp_bo_test = np.mean(total_disp_bo_test, axis = 0)
    mean_disp_mitigated_test = np.mean(total_disp_mitigated_test, axis = 0)
    
    mean_acc_bias_train = np.mean(total_acc_bias_train, axis = 0)
    mean_acc_bo_train = np.mean(total_acc_bo_train, axis = 0)
    mean_acc_mitigated_train = np.mean(total_acc_mitigated_train, axis = 0)
    
    mean_acc_bias_test = np.mean(total_acc_bias_test, axis = 0)
    mean_acc_bo_test = np.mean(total_acc_bo_test, axis = 0)
    mean_acc_mitigated_test = np.mean(total_acc_mitigated_test, axis = 0)
    
    y_err_fidel_maj = np.std(total_fidel_maj, axis = 0)
    y_err_fidel_min = np.std(total_fidel_min, axis = 0)
    y_err_fidel = np.std(total_fidel, axis = 0)
    
    df_disp = pd.DataFrame({"Biased Train" : mean_disp_bias_train,
                       "BO Train" : mean_disp_bo_train,
                       "Mitigated Train" : mean_disp_mitigated_train,
                       "Biased Test" : mean_disp_bias_test,
                       "BO Test" : mean_disp_bo_test,
                       "Mitigated Test" : mean_disp_mitigated_test})
    
    df_acc = pd.DataFrame({"Biased Train" : mean_acc_bias_train,
                       "BO Train" : mean_acc_bo_train,
                       "Mitigated Train" : mean_acc_mitigated_train,
                       "Biased Test" : mean_acc_bias_test,
                       "BO Test" : mean_acc_bo_test,
                       "Mitigated Test" : mean_acc_mitigated_test})
   
    return bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df_disp, df_acc

# %% [markdown]
# ### Section 4

# %%
#Run experiments for section 4 and save data
import warnings
import time
warnings.simplefilter(action='ignore', category=FutureWarning)

for n in [300,3000,30000]:
#for n in [30000]:

    random.seed(42)
    np.random.seed(42)

    eta = 0.4
    r = 0.2
    num_iters = 50
    
    print(f'n={n}')
    
    print(f'Run simulation with intervention...')
    start_time = time.time()
    apply_fairness = True
    bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df_disp, df_acc = \
    tradeoff_visualization_error(r=r, n=n, apply_fairness=apply_fairness,verbose=False, num_iters=num_iters)
    df_res = pd.DataFrame(np.array([bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel]).T, columns=['bias_amts', 'mean_fidel_maj', 'mean_fidel_min', 'mean_fidel', 'y_err_fidel_maj', 'y_err_fidel_min', 'y_err_fidel'])
    df_disp.to_csv(f'disp_with_intervention_numiters{num_iters}_n{n}_eta{eta}_fairness{apply_fairness}.csv', index = True)
    df_res.to_csv(f'fid_with_intervention_numiters{num_iters}_n{n}_eta{eta}_fairness{apply_fairness}.csv', index = True)
    df_acc.to_csv(f'acc_with_intervention_numiters{num_iters}_n{n}_eta{eta}_fairness{apply_fairness}.csv', index = True)
    print(f'Took {(time.time() - start_time)/60} minutes.')
    
    print(f'Run simulation without intervention...')
    start_time = time.time()
    apply_fairness = False
    bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df_disp, df_acc = \
    tradeoff_visualization_error(r = r, n = n, apply_fairness=apply_fairness,verbose=False, num_iters=num_iters)
    df_res = pd.DataFrame(np.array([bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel]).T, columns=['bias_amts', 'mean_fidel_maj', 'mean_fidel_min', 'mean_fidel', 'y_err_fidel_maj', 'y_err_fidel_min', 'y_err_fidel'])
    df_disp.to_csv(f'disp_without_intervention_numiters{num_iters}_n{n}_eta{eta}_fairness{apply_fairness}.csv', index = True)
    df_res.to_csv(f'fid_without_intervention_numiters{num_iters}_n{n}_eta{eta}_fairness{apply_fairness}.csv', index = True)
    df_acc.to_csv(f'acc_without_intervention_numiters{num_iters}_n{n}_eta{eta}_fairness{apply_fairness}.csv', index = True)
    print(f'Took {(time.time() - start_time)/60} minutes.')
# Out:
# n=300
# Run simulation with intervention...
# Diff:  -0.06250000000000006
# Beta:  1.0
#
# Total Deleted:  0 	 % Deleted:  0.0
# COEF:  [[ 0.1461888  -0.04585094  0.4768788  -0.02306041  0.17037041  0.13915802]]
# INTERCEPT:  [0.10458195]
# Beta:  0.9
#
# Total Deleted:  3 	 % Deleted:  0.09090909090909091
# COEF:  [[ 0.1461888  -0.04585094  0.4768788  -0.02306041  0.17037041  0.13915802]]
# INTERCEPT:  [0.10458195]
# Beta:  0.8
#
# Total Deleted:  5 	 % Deleted:  0.15151515151515152
# COEF:  [[ 0.1461888  -0.04585094  0.4768788  -0.02306041  0.17037041  0.13915802]]
# INTERCEPT:  [0.10458195]
# Beta:  0.7
#
# Total Deleted:  9 	 % Deleted:  0.2727272727272727
# COEF:  [[ 0.1461888  -0.04585094  0.4768788  -0.02306041  0.17037041  0.13915802]]
# INTERCEPT:  [0.10458195]
# Beta:  0.6
#
# Total Deleted:  13 	 % Deleted:  0.3939393939393939
# COEF:  [[ 0.1461888  -0.04585094  0.4768788  -0.02306041  0.17037041  0.13915802]]
# INTERCEPT:  [0.10458195]
# Beta:  0.5
#
# Total Deleted:  20 	 % Deleted:  0.6060606060606061
# COEF:  [[ 0.1461888  -0.04585094  0.4768788  -0.02306041  0.17037041  0.13915802]]
# INTERCEPT:  [0.10458195]
# Beta:  0.4
#
# Total Deleted:  23 	 % Deleted:  0.696969696969697
# COEF:  [[ 0.1461888  -0.04585094  0.4768788  -0.02306041  0.17037041  0.13915802]]
# INTERCEPT:  [0.10458195]
# Beta:  0.3
#
# Total Deleted:  29 	 % Deleted:  0.8787878787878788
# COEF:  [[ 0.1461888  -0.04585094  0.4768788  -0.02306041  0.17037041  0.13915802]]
# INTERCEPT:  [0.10458195]
# Beta:  0.2
#
# Total Deleted:  25 	 % Deleted:  0.7575757575757576
# COEF:  [[ 0.1461888  -0.04585094  0.4768788  -0.02306041  0.17037041  0.13915802]]
# INTERCEPT:  [0.10458195]
# Beta:  0.1
#
# Total Deleted:  31 	 % Deleted:  0.9393939393939394
# COEF:  [[ 0.1461888  -0.04585094  0.4768788  -0.02306041  0.17037041  0.13915802]]
# INTERCEPT:  [0.10458195]
# Beta:  0.0
#
# Total Deleted:  33 	 % Deleted:  1.0
# COEF:  [[ 0.1461888  -0.04585094  0.4768788  -0.02306041  0.17037041  0.13915802]]
# INTERCEPT:  [0.10458195]
# Diff:  -0.11041666666666672
# Total Deleted:  0 	 % Deleted:  0.0
# COEF:  [[ 0.04879553 -0.19954689  0.13249944 -0.29275379  0.14136426  0.18001573]]
# INTERCEPT:  [-0.13870363]
# Total Deleted:  2 	 % Deleted:  0.08695652173913043
# COEF:  [[ 0.04879553 -0.19954689  0.13249944 -0.29275379  0.14136426  0.18001573]]
# INTERCEPT:  [-0.13870363]
# Total Deleted:  2 	 % Deleted:  0.08695652173913043
# COEF:  [[ 0.04879553 -0.19954689  0.13249944 -0.29275379  0.14136426  0.18001573]]
# INTERCEPT:  [-0.13870363]
# Total Deleted:  5 	 % Deleted:  0.21739130434782608
# COEF:  [[ 0.04879553 -0.19954689  0.13249944 -0.29275379  0.14136426  0.18001573]]
# INTERCEPT:  [-0.13870363]
# Total Deleted:  8 	 % Deleted:  0.34782608695652173
# COEF:  [[ 0.04879553 -0.19954689  0.13249944 -0.29275379  0.14136426  0.18001573]]
# INTERCEPT:  [-0.13870363]
# Total Deleted:  12 	 % Deleted:  0.5217391304347826
# COEF:  [[ 0.04879553 -0.19954689  0.13249944 -0.29275379  0.14136426  0.18001573]]
# INTERCEPT:  [-0.13870363]
# Total Deleted:  16 	 % Deleted:  0.6956521739130435
# COEF:  [[ 0.04879553 -0.19954689  0.13249944 -0.29275379  0.14136426  0.18001573]]
# INTERCEPT:  [-0.13870363]
# Total Deleted:  17 	 % Deleted:  0.7391304347826086
# COEF:  [[ 0.04879553 -0.19954689  0.13249944 -0.29275379  0.14136426  0.18001573]]
# INTERCEPT:  [-0.13870363]
# Total Deleted:  19 	 % Deleted:  0.8260869565217391
# COEF:  [[ 0.04879553 -0.19954689  0.13249944 -0.29275379  0.14136426  0.18001573]]
# INTERCEPT:  [-0.13870363]
# Total Deleted:  23 	 % Deleted:  1.0
# COEF:  [[ 0.04879553 -0.19954689  0.13249944 -0.29275379  0.14136426  0.18001573]]
# INTERCEPT:  [-0.13870363]
# Total Deleted:  23 	 % Deleted:  1.0
# COEF:  [[ 0.04879553 -0.19954689  0.13249944 -0.29275379  0.14136426  0.18001573]]
# INTERCEPT:  [-0.13870363]
# Diff:  -0.04583333333333328
# Total Deleted:  0 	 % Deleted:  0.0
# COEF:  [[ 0.28906064 -0.40216972  0.33892981 -0.43680113  0.14375112  0.46207671]]
# INTERCEPT:  [0.11706301]
# Total Deleted:  5 	 % Deleted:  0.13157894736842105
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-60a8bd0b565a> in <module>
#      20     apply_fairness = True
#      21     bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df_disp, df_acc = \
# ---> 22     tradeoff_visualization_error(r=r, n=n, apply_fairness=apply_fairness,verbose=False, num_iters=num_iters)
#      23     df_res = pd.DataFrame(np.array([bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel]).T, columns=['bias_amts', 'mean_fidel_maj', 'mean_fidel_min', 'mean_fidel', 'y_err_fidel_maj', 'y_err_fidel_min', 'y_err_fidel'])
#      24     df_disp.to_csv(f'disp_with_intervention_numiters{num_iters}_n{n}_eta{eta}_fairness{apply_fairness}.csv', index = True)
#
# <ipython-input-16-bb5522c93463> in tradeoff_visualization_error(r, n, apply_fairness, verbose, num_iters)
#     127             error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
#     128             disparity = EqualizedOdds()
# --> 129             disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
#     130             #print(f'     Train error = {error.gamma(classify)[0]}')
#     131             #print(f'     Train disparity = {disparity.gamma(classify).max()}')
#
# ~/Library/Python/3.7/lib/python/site-packages/fairlearn/reductions/_moments/utility_parity.py in load_data(self, X, y, sensitive_features, control_features)
#     474                                          control_features=control_features)
#     475
# --> 476         base_event = y_train.apply(lambda v: _LABEL + "=" + str(v))
#     477         event = _merge_event_and_control_columns(base_event, cf_train)
#     478         super().load_data(X, y_train, event=event, sensitive_features=sf_train)
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/Library/Python/3.7/lib/python/site-packages/fairlearn/reductions/_moments/utility_parity.py in <lambda>(v)
#     474                                          control_features=control_features)
#     475
# --> 476         base_event = y_train.apply(lambda v: _LABEL + "=" + str(v))
#     477         event = _merge_event_and_control_columns(base_event, cf_train)
#     478         super().load_data(X, y_train, event=event, sensitive_features=sf_train)
#
# KeyboardInterrupt:

# %%
#Make plots for section 4

for n in [300,3000,30000]:

    eta = 0.4
    num_iters = 50

    df_fair = pd.read_csv(f'fid_with_intervention_numiters{num_iters}_n{n}_eta{eta}_fairnessTrue.csv')
    df_bias = pd.read_csv(f'fid_without_intervention_numiters{num_iters}_n{n}_eta{eta}_fairnessFalse.csv')

    a = 0.5
    fig, ax = plt.subplots(figsize=(5,5))
    markers, caps, bars = ax.errorbar(1-df_fair.bias_amts, df_fair.mean_fidel_maj, yerr = df_fair.y_err_fidel_maj, 
                                      label = 'With intervention majority group', color = "orange",
                                      capsize=4, capthick=2)
    [bar.set_alpha(a) for bar in bars]
    [cap.set_alpha(a) for cap in caps]
    markers, caps, bars = ax.errorbar(1-df_fair.bias_amts, df_fair.mean_fidel_min, yerr = df_fair.y_err_fidel_min, 
                                      label = 'With intervention minority group', color = "orange",
                                      capsize=4, capthick=2, linestyle='--')
    [bar.set_linestyle('--') for bar in bars]
    [bar.set_alpha(a) for bar in bars]
    [cap.set_alpha(a) for cap in caps]
    markers, caps, bars = ax.errorbar(1-df_bias.bias_amts, df_bias.mean_fidel_maj, yerr = df_bias.y_err_fidel_maj, 
                                      label = 'Without intervention majority group', color = "blue",
                                      capsize=4, capthick=2)
    [bar.set_alpha(a) for bar in bars]
    [cap.set_alpha(a) for cap in caps]
    markers, caps, bars = ax.errorbar(1-df_bias.bias_amts, df_bias.mean_fidel_min, yerr = df_bias.y_err_fidel_min, 
                                      label = 'Without intervention minority group', color = "blue",
                                      capsize=4, capthick=2, linestyle='--')
    [bar.set_linestyle('--') for bar in bars]
    [bar.set_alpha(a) for bar in bars]
    [cap.set_alpha(a) for cap in caps]
    
    #plt.errorbar(df_fair.bias_amts, df_fair.mean_fidel_maj, yerr = df_fair.y_err_fidel_maj, label = 'With intervention majority group', color = "orange")
    #plt.errorbar(df_fair.bias_amts, df_fair.mean_fidel_min, yerr = df_fair.y_err_fidel_min, label = 'With intervention minority group', color = "orange", linestyle = '--')
    #plt.errorbar(df_bias.bias_amts, df_bias.mean_fidel_maj, yerr = df_bias.y_err_fidel_maj, label = 'Without intervention majority group', color = "blue")
    #plt.errorbar(df_bias.bias_amts, df_bias.mean_fidel_min, yerr = df_bias.y_err_fidel_min, label = 'Without intervention minority group', color = "blue", linestyle = '--')
    #plt.errorbar(bias_amts, mean_fidel, yerr = y_err_fidel, label = 'Total Fidelity', color = "blue")
    
    plt.xlabel(r"Amount of injected underrep. bias $1-\beta$")
    plt.ylabel(f"Fidelity with n={n}")
    #plt.xlim(1.05, -0.05)
    plt.ylim(0.35, 1.05)
    if n == 30000:
        plt.legend()
    plt.savefig(f'section4_n{n}.jpg',dpi=300)
    plt.show()

# %%
for n in [300,3000,30000]:

    eta = 0.4
    num_iters = 50

    df_fair = pd.read_csv(f'fid_with_intervention_numiters{num_iters}_n{n}_eta{eta}_fairnessTrue.csv')
    df_bias = pd.read_csv(f'fid_with_intervention_numiters{num_iters}_n{n}_eta{eta}_fairnessFalse.csv')
    
    print(f'\nn={n}')
    print(f'Overall fid = {df_fair.mean_fidel.describe()}')
    print(f'Min fid = {df_fair.mean_fidel_min.describe()}')

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

random.seed(42)
np.random.seed(42)

eta = 0.2
n = 30000
r = 0.2
num_iters = 10

bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df = \
tradeoff_visualization_error(classifier,r = r, n = n, apply_fairness=True,verbose=True, num_iters=num_iters)

df.to_csv(f'with_intervention_numiters{num_iters}_n{n}_eta{eta}.csv', index = True)

# %%
plt.figure(figsize=(10,7))
plt.errorbar(bias_amts, mean_fidel_maj, yerr = y_err_fidel_maj, label = 'Fidelity Majority', color = "red")
plt.errorbar(bias_amts, mean_fidel_min, yerr = y_err_fidel_min, label = 'Fidelity Minority', color = "green")
#plt.errorbar(bias_amts, mean_fidel, yerr = y_err_fidel, label = 'Total Fidelity', color = "blue")
plt.xlabel("Beta Value")
plt.ylabel("Fidelity")
plt.xlim(1.05, -0.05)
plt.ylim(0.92, 1)
plt.legend()
plt.title("Fidelity Plot")
plt.savefig(f'with_intervention_numiters{num_iters}_n{n}_eta{eta}.jpg')
plt.show()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

random.seed(42)
np.random.seed(42)

eta = 0.4
n = 30000
r = 0.2
num_iters = 10

bias_amts, mean_fidel_maj2, mean_fidel_min2, mean_fidel2, y_err_fidel_maj2, y_err_fidel_min2, y_err_fidel2, df = \
tradeoff_visualization_error(classifier,r = r, n = n, apply_fairness=False,verbose=True, num_iters=num_iters)

df.to_csv(f'without_intervention_numiters{num_iters}_n{n}_eta{eta}.csv', index = True)

# %%
plt.figure(figsize=(10,7))
plt.errorbar(bias_amts, mean_fidel_maj2, yerr = y_err_fidel_maj2, label = 'Fidelity Majority', color = "red")
plt.errorbar(bias_amts, mean_fidel_min2, yerr = y_err_fidel_min2, label = 'Fidelity Minority', color = "green")
plt.errorbar(bias_amts, mean_fidel2, yerr = y_err_fidel2, label = 'Total Fidelity', color = "blue")
plt.xlabel("Beta Value")
plt.ylabel("Fidelity")
plt.xlim(1.05, -0.05)
plt.legend()
plt.title("Fidelity Plot")
plt.savefig(f'without_intervention_numiters{num_iters}_n{n}_eta{eta}.jpg')
plt.show()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

random.seed(42)
np.random.seed(42)

eta = 0.4
n = 100000
r = 0.2
num_iters = 10

bias_amts, mean_fidel_maj2, mean_fidel_min2, mean_fidel2, y_err_fidel_maj2, y_err_fidel_min2, y_err_fidel2, df = \
tradeoff_visualization_error(classifier,r = r, n = n, apply_fairness=True,verbose=True, num_iters=num_iters)

df.to_csv(f'with_intervention_numiters{num_iters}_n{n}_eta{eta}.csv', index = True)

# %%
plt.figure(figsize=(10,7))
plt.errorbar(bias_amts, mean_fidel_maj2, yerr = y_err_fidel_maj2, label = 'Fidelity Majority', color = "red")
plt.errorbar(bias_amts, mean_fidel_min2, yerr = y_err_fidel_min2, label = 'Fidelity Minority', color = "green")
plt.errorbar(bias_amts, mean_fidel2, yerr = y_err_fidel2, label = 'Total Fidelity', color = "blue")
plt.xlabel("Beta Value")
plt.ylabel("Fidelity")
plt.xlim(1.05, -0.05)
plt.legend()
plt.title("Fidelity Plot")
plt.savefig(f'with_intervention_numiters{num_iters}_n{n}_eta{eta}.jpg')
plt.show()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

random.seed(42)
np.random.seed(42)

eta = 0.4
n = 100000
r = 0.2
num_iters = 10

bias_amts, mean_fidel_maj2, mean_fidel_min2, mean_fidel2, y_err_fidel_maj2, y_err_fidel_min2, y_err_fidel2, df = \
tradeoff_visualization_error(classifier,r = r, n = n, apply_fairness=False,verbose=True, num_iters=num_iters)

df.to_csv(f'with_intervention_numiters{num_iters}_n{n}_eta{eta}.csv', index = True)

# %%
plt.figure(figsize=(10,7))
plt.errorbar(bias_amts, mean_fidel_maj2, yerr = y_err_fidel_maj2, label = 'Fidelity Majority', color = "red")
plt.errorbar(bias_amts, mean_fidel_min2, yerr = y_err_fidel_min2, label = 'Fidelity Minority', color = "green")
plt.errorbar(bias_amts, mean_fidel2, yerr = y_err_fidel2, label = 'Total Fidelity', color = "blue")
plt.xlabel("Beta Value")
plt.ylabel("Fidelity")
plt.xlim(1.05, -0.05)
plt.legend()
plt.title("Fidelity Plot")
plt.savefig(f'without_intervention_numiters{num_iters}_n{n}_eta{eta}.jpg')
plt.show()

# %% [markdown]
# # Exploration (Section 5)

# %% [markdown]
# ## Representation

# %%
def representation(r, n, apply_fairness = True, verbose = False, num_iters = 10, inter = False, diff_base = False):
    
    total_fidel_maj = []
    total_fidel_min = []
    total_fidel = []
    
    total_disp_bias_train = []
    total_disp_bo_train = []
    total_disp_mitigated_train = []
    
    total_disp_bias_test = []
    total_disp_bo_test = []
    total_disp_mitigated_test = []
    
    for i in range(num_iters):
    
        # 1 to 0 in increments of 0.1
        bias_amts = np.divide(list(range(10,-1,-1)),10)
        if inter == False: bias_amts[-1] = 0.01

        test_maj = []
        test_min = []
        total = []
        
        disp_bias_train = []
        disp_bo_train = []
        disp_mitigated_train = []
        
        disp_bias_test = []
        disp_bo_test = []
        disp_mitigated_test = []
        
        count = 0
        
        if diff_base: 
            outcome_continuous, df_synthetic = true_label_generation(r=r, eta=eta, n=2*n, maj_means =[0.7,0.7,0.7])
        else: outcome_continuous, df_synthetic = true_label_generation(r=r, eta=eta, n=2*n)        
        
        threshold = 0.5
        exact_bo_labels = np.where(outcome_continuous < threshold, 0, 1)
        exact_bo_labels_train = np.array(exact_bo_labels[range(0,n)])
        exact_bo_labels_test = np.array(exact_bo_labels[range(n,len(df_synthetic))])
        
        # split into train and test
        df_train = df_synthetic.loc[range(0,n), :]
        
        df_train_transf, maj_list, min_list = transform(df_train, True, True)
        
        df_test = df_synthetic.loc[range(n, len(df_synthetic)),:]
        df_test_transf, maj_list, min_list = transform(df_test, True, False)
        
        df_test_maj = df_test_transf.loc[maj_list]
        df_test_min = df_test_transf.loc[min_list]

        # format training data
        X_true = df_train_transf.iloc[:, :-1].values
        y_true = df_train_transf.iloc[:, -1].values
        
        # format test data
        X_test = df_test_transf.iloc[:, :-1].values
        X_test_maj = df_test_maj.iloc[:, :-1].values
        X_test_min = df_test_min.iloc[:, :-1].values
        y_test = df_test_transf.iloc[:, -1].values
        y_test_maj = df_test_maj.iloc[:, -1].values
        y_test_min = df_test_min.iloc[:, -1].values
        
        sens_attr_test = df_test['cat']
        
        for beta in bias_amts:
            
            if i == 0: print("Beta: ", beta, '\n')

            df_train_copy = df_train.copy()

            df_majority = df_train_copy[df_train_copy['cat'] == 1]
            df_minority = df_train_copy[df_train_copy['cat'] == 0]

            if inter:
                # unfavored group with negative label
                df_minority_negative = df_minority[df_minority['outcome'] == 0.0]

                # unfavored group with positive label (preferred)
                df_minority_positive = df_minority[df_minority['outcome'] == 1.0]

                # data frame without positively labeled examples from minority class
                df_total = pd.concat([df_majority, df_minority_negative])

                df_undersampled = under(df_minority_positive, beta)

                # combine undersampled and original favored class to create dataset
                df_concat = pd.concat([df_total,df_undersampled]).sample(frac=1, random_state = 42) # permute data

            else:
                df_undersampled = under(df_minority, beta)

                # combine undersampled and original favored class to create dataset
                df_concat = pd.concat([df_majority,df_undersampled])
                df_concat.sample(frac=1, random_state = 42) # permute data

            # format data
            X_bias_true, y_bias_true, df_sens = transform(df_concat)
            
            # model trained on biased data
            classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none')
            classifier_bias = classifier.fit(X_bias_true, y_bias_true)
            
            acc = accuracy_score(y_test,classifier_bias.predict(X_test))
            #print(f'Biased classifier:')
            #print(f'     Test accuracy = {acc}')
            
            m = classifier_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            disparity = EqualizedOdds()
            disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            #print(f'     Train error = {error.gamma(classify)[0]}')
            #print(f'     Train disparity = {disparity.gamma(classify).max()}')
            disp_bias_train += [disparity.gamma(classify).max()]

            m = classifier_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            disparity = EqualizedOdds()
            disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            #print(f'     Test error = {error.gamma(classify)[0]}')
            #print(f'     Test disparity = {disparity.gamma(classify).max()}')
            disp_bias_test += [disparity.gamma(classify).max()]
            
            # Learned bayes optimal classifier
            classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none')
            classifier_b = classifier.fit(X_true, y_true)                
            #classifier_b = clone(classifier).fit(X_true, y_true)
            acc = accuracy_score(y_test,classifier_b.predict(X_test))
            #print(f'Learned BO classifier:')
            #print(f'     Test accuracy = {acc}')
            
            m = classifier_b
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            disparity = EqualizedOdds()
            disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            #print(f'     Train error = {error.gamma(classify)[0]}')
            #print(f'     Train disparity = {disparity.gamma(classify).max()}')
            disp_bo_train += [disparity.gamma(classify).max()]

            m = classifier_b
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            disparity = EqualizedOdds()
            disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            #print(f'     Test error = {error.gamma(classify)[0]}')
            #print(f'     Test disparity = {disparity.gamma(classify).max()}')
            disp_bo_test += [disparity.gamma(classify).max()]
            
            
            # Exact BO optimal classifier
            #print(f'Exact BO classifier:')
            acc = accuracy_score(y_test,exact_bo_labels_test)
            #print(f'     Test accuracy = {acc}')
            acc = accuracy_score(y_true,exact_bo_labels_train)
            #print(f'     Train accuracy = {acc}')

            if apply_fairness:
                constraint = EqualizedOdds()
                classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none', fit_intercept = False, max_iter = 200)   

                classifier_mitigated_bias = GridSearch(estimator=classifier,
                                                       constraints=constraint,
                                                       selection_rule='tradeoff_optimization',
                                                       constraint_weight=0.5,
                                                       grid_size=10,
                                                       grid_limit=2.0,
                                                       grid_offset=None,
                                                       grid=None,
                                                       sample_weight_name='sample_weight')
                                                       
                classifier_mitigated_bias.fit(X_bias_true, y_bias_true, sensitive_features = df_sens)
                
                acc = accuracy_score(y_test,classifier_mitigated_bias.predict(X_test))
                #print(f'Mitigated bias classifier:')
                #print(f'     Test accuracy = {acc}')
                
                m = classifier_mitigated_bias
                def classify(X): return m.predict(X)
                error = ErrorRate()
                error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
                disparity = EqualizedOdds()
                disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
                #print(f'     Train error = {error.gamma(classify)[0]}')
                #print(f'     Train disparity = {disparity.gamma(classify).max()}')
                disp_mitigated_train += [disparity.gamma(classify).max()]
                
                m = classifier_mitigated_bias
                def classify(X): return m.predict(X)
                error = ErrorRate()
                error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
                disparity = EqualizedOdds()
                disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
                #print(f'     Test error = {error.gamma(classify)[0]}')
                #print(f'     Test disparity = {disparity.gamma(classify).max()}')
                disp_mitigated_test += [disparity.gamma(classify).max()]
                
                # Alternative fidelity of intervention model to no intervention model
                alt_fid_train = accuracy_score(classifier_mitigated_bias.predict(X_bias_true),classifier_bias.predict(X_bias_true))
                alt_fid_test = accuracy_score(classifier_mitigated_bias.predict(X_test),classifier_bias.predict(X_test))
                #print(f'Alternative fidelity of intervention model to no intervention model: train = {alt_fid_train}, test = {alt_fid_test}')
                

            else:
                classifier_mitigated_bias = clone(classifier_bias)
                classifier_mitigated_bias.fit(X_bias_true, y_bias_true)
                
                # NOTE: disparities are the same as for classifier_bias

                
            # Fidelity in this step
            fid = accuracy_score(classifier_mitigated_bias.predict(X_test),classifier_b.predict(X_test))
            #print(f'Test set fidelity of learned BO classifier and mitigated_bias_classifier: {fid}')
            fid = accuracy_score(classifier_mitigated_bias.predict(X_test),exact_bo_labels_test)
            #print(f'Test set fidelity of exact BO classifier and mitigated biased classifier: {fid}')
            fid = accuracy_score(classifier_bias.predict(X_test),classifier_b.predict(X_test))
            #print(f'Test set fidelity of learned BO classifier and biased classifier: {fid}')
            
            # fidelity check
            test_maj += [accuracy_score(classifier_mitigated_bias.predict(X_test_maj), classifier_b.predict(X_test_maj))]
            test_min += [accuracy_score(classifier_mitigated_bias.predict(X_test_min), classifier_b.predict(X_test_min))]
            total += [accuracy_score(classifier_mitigated_bias.predict(X_test), classifier_b.predict(X_test))]
                
            if verbose:
                print("Finished Iteration: ", count)
                count +=1
        
        #print(f'Fidelity test maj: {test_maj}')
        #print(f'Fidelity test min: {test_maj}')
        
        total_fidel_maj.append(test_maj)
        total_fidel_min.append(test_min)
        total_fidel.append(total)
        
        total_disp_bias_train.append(disp_bias_train)
        total_disp_bo_train.append(disp_bo_train)
        total_disp_mitigated_train.append(disp_mitigated_train)

        total_disp_bias_test.append(disp_bias_test)
        total_disp_bo_test.append(disp_bo_test)
        total_disp_mitigated_test.append(disp_mitigated_test)
        
        if verbose:
                print("Finished Total Iteration: ", i+1)
    
    mean_fidel_maj = np.mean(total_fidel_maj, axis = 0)
    mean_fidel_min = np.mean(total_fidel_min, axis = 0)
    mean_fidel = np.mean(total_fidel, axis = 0)
    
    mean_disp_bias_train = np.mean(total_disp_bias_train, axis = 0)
    mean_disp_bo_train = np.mean(total_disp_bo_train, axis = 0)
    mean_disp_mitigated_train = np.mean(total_disp_mitigated_train, axis = 0)
    
    mean_disp_bias_test = np.mean(total_disp_bias_test, axis = 0)
    mean_disp_bo_test = np.mean(total_disp_bo_test, axis = 0)
    mean_disp_mitigated_test = np.mean(total_disp_mitigated_test, axis = 0)
    
    y_err_fidel_maj = np.std(total_fidel_maj, axis = 0)
    y_err_fidel_min = np.std(total_fidel_min, axis = 0)
    y_err_fidel = np.std(total_fidel, axis = 0)
    
    df = pd.DataFrame({"Biased Train" : mean_disp_bias_train,
                       "BO Train" : mean_disp_bo_train,
                       "Mitigated Train" : mean_disp_mitigated_train,
                       "Biased Test" : mean_disp_bias_test,
                       "BO Test" : mean_disp_bo_test,
                       "Mitigated Test" : mean_disp_mitigated_test})
   
    return bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df

# %%
random.seed(42)
np.random.seed(42)

eta = 0.4
n = 30000
r = 0.2
num_iters = 50

bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df = \
representation(r = r, n = n, apply_fairness=True,verbose=True, num_iters=num_iters, diff_base = False, inter = False)

df.to_csv('disp_repr_no_inter.csv', index = True)
df_res = pd.DataFrame(np.array([bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel]).T, columns=['bias_amts', 'mean_fidel_maj', 'mean_fidel_min', 'mean_fidel', 'y_err_fidel_maj', 'y_err_fidel_min', 'y_err_fidel'])
df_res.to_csv(f'fid_repr_no_inter.csv', index = True)
# Out:
# Diff:  0.008458333333333345
# Beta:  1.0
#
# Total Deleted:  0 	 % Deleted:  0.0
# Finished Iteration:  0
# Beta:  0.9
#
# Total Deleted:  601 	 % Deleted:  0.10145172180958811
# Finished Iteration:  1
# Beta:  0.8
#
# Total Deleted:  1236 	 % Deleted:  0.2086428089128967
# Finished Iteration:  2
# Beta:  0.7
#
# Total Deleted:  1809 	 % Deleted:  0.30536799459824443
# Finished Iteration:  3
# Beta:  0.6
#
# Total Deleted:  2306 	 % Deleted:  0.38926401080351114
# Finished Iteration:  4
# Beta:  0.5
#
# Total Deleted:  2962 	 % Deleted:  0.5
# Finished Iteration:  5
# Beta:  0.4
#
# Total Deleted:  3579 	 % Deleted:  0.6041525995948683
# Finished Iteration:  6
# Beta:  0.3
#
# Total Deleted:  4085 	 % Deleted:  0.6895678595543552
# Finished Iteration:  7
# Beta:  0.2
#
# Total Deleted:  4729 	 % Deleted:  0.7982781904118839
# Finished Iteration:  8
# Beta:  0.1
#
# Total Deleted:  5331 	 % Deleted:  0.899898717083052
# Finished Iteration:  9
# Beta:  0.01
#
# Total Deleted:  5872 	 % Deleted:  0.9912221471978393
# Finished Iteration:  10
# Finished Total Iteration:  1
# Diff:  0.010937499999999989
# Total Deleted:  0 	 % Deleted:  0.0
# Finished Iteration:  0
# Total Deleted:
# Total Deleted:  0 	 % Deleted:  0.0
# Finished Iteration:  0
# Total Deleted:  597 	 % Deleted:  0.09853111074434726
# Finished Iteration:  1
# Total Deleted:  1223 	 % Deleted:  0.2018484898498102
# Finished Iteration:  2
# Total Deleted:  1762 	 % Deleted:  0.29080706387192606
# Finished Iteration:  3
# Total Deleted:  2428 	 % Deleted:  0.4007261924409969
# Finished Iteration:  4
# Total Deleted:  3036 	 % Deleted:  0.5010727842878363
# Finished Iteration:  5
# Total Deleted:  3596 	 % Deleted:  0.5934972767783463
# Finished Iteration:  6
# Total Deleted:  4229 	 % Deleted:  0.6979699620399406
# Finished Iteration:  7
# Total Deleted:  4843 	 % Deleted:  0.7993068163063212
# Finished Iteration:  8
# Total Deleted:  5467 	 % Deleted:  0.9022941079386038
# Finished Iteration:  9
# Total Deleted:  6000 	 % Deleted:  0.9902624195411784
# Finished Iteration:  10
# Finished Total Iteration:  50

# %%
bias_amts = np.divide(list(range(10,-1,-1)),10)
plt.figure(figsize=(10,7))
plt.errorbar(bias_amts, mean_fidel_maj21, yerr = y_err_fidel_maj21, label = 'Fidelity Majority', color = "red")
plt.errorbar(bias_amts, mean_fidel_min21, yerr = y_err_fidel_min21, label = 'Fidelity Minority', color = "green")
plt.xlabel("Beta Value for Minority")
plt.ylabel("Fidelity")
plt.xlim(1.05, -0.05)
plt.ylim(0.92, 1)
plt.legend()
plt.title("Fidelity Plot")
plt.savefig('repr_no_inter.jpg')
plt.show()

# %%
df_repr = pd.read_csv('fid_repr_no_inter.csv')
plt.figure(figsize=(10,7))
plt.errorbar(df_repr.bias_amts, df_repr.mean_fidel_maj, yerr = df_repr.y_err_fidel_maj, label = 'Fidelity Majority', color = "red")
plt.errorbar(df_repr.bias_amts, df_repr.mean_fidel_min, yerr = df_repr.y_err_fidel_min, label = 'Fidelity Minority', color = "green")
plt.xlabel("Beta Value for Minority")
plt.ylabel("Fidelity")
plt.xlim(1.05, -0.05)
plt.ylim(0.92, 1)
plt.legend()
plt.title("Fidelity Plot")
plt.savefig('repr_no_inter.jpg')
plt.show()

# %%
random.seed(42)
np.random.seed(42)

eta = 0.4
n = 30000
r = 0.2
num_iters = 50

bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df = \
representation(r = r, n = n, apply_fairness=True,verbose=True, num_iters=num_iters, diff_base = False, inter = True)

df.to_csv('disp_repr_inter.csv', index = True)
df_res = pd.DataFrame(np.array([bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel]).T, columns=['bias_amts', 'mean_fidel_maj', 'mean_fidel_min', 'mean_fidel', 'y_err_fidel_maj', 'y_err_fidel_min', 'y_err_fidel'])
df_res.to_csv(f'fid_repr_inter.csv', index = True)
# Out:
# Diff:  0.008458333333333345
# Beta:  1.0
#
# Total Deleted:  0 	 % Deleted:  0.0
# Finished Iteration:  0
# Beta:  0.9
#
# Total Deleted:  298 	 % Deleted:  0.10215975317106617
# Finished Iteration:  1
# Beta:  0.8
#
# Total Deleted:  574 	 % Deleted:  0.19677751114158382
# Finished Iteration:  2
# Beta:  0.7
#
# Total Deleted:  875 	 % Deleted:  0.2999657182036339
# Finished Iteration:  3
# Beta:  0.6
#
# Total Deleted:  1180 	 % Deleted:  0.4045251971203291
# Finished Iteration:  4
# Beta:  0.5
#
# Total Deleted:  1481 	 % Deleted:  0.5077134041823792
# Finished Iteration:  5
# Beta:  0.4
#
# Total Deleted:  1766 	 % Deleted:  0.6054165238258484
# Finished Iteration:  6
# Beta:  0.3
#
# Total Deleted:  2107 	 % Deleted:  0.7223174494343504
# Finished Iteration:  7
# Beta:  0.2
#
# Total Deleted:  2329 	 % Deleted:  0.798423037367158
# Finished Iteration:  8
# Beta:  0.1
#
# Total Deleted:  2625 	 % Deleted:  0.8998971546109016
# Finished Iteration:  9
# Beta:  0.01
#
# Total Deleted:  2881 	 % Deleted:  0.9876585533081933
# Finished Iteration:  10
# Finished Total Iteration:  1
# Diff:  0.010937499999999989
# Total Deleted:  0 	 % Deleted:  0.0
# Finished Iteration:  0
# Total Deleted:  283 	 % Deleted:  0.0950621430970776
# Finished Iteration:  1
# Total Deleted:  627 	 % Deleted:  0.2106147127981189
# Finished Iteration:  2
# Total Deleted:  905 	 % Deleted:  0.30399731273093716
# Finished Iteration:  3
# Total Deleted:  1189 	 % Deleted:  0.39939536446086665
# Finished Iteration:  4
# Total Deleted:  1507 	 % Deleted:  0.5062143097077595
# Finished Iteration:  5
# Total Deleted:  0 	 % Deleted:  0.0
# Finished Iteration:  0
# Total Deleted:  312 	 % Deleted:  0.10684931506849316
# Finished Iteration:  1
# Total Deleted:  598 	 % Deleted:  0.2047945205479452
# Finished Iteration:  2
# Total Deleted:  876 	 % Deleted:  0.3
# Finished Iteration:  3
# Total Deleted:  1174 	 % Deleted:  0.40205479452054793
# Finished Iteration:  4
# Total Deleted:  1461 	 % Deleted:  0.5003424657534247
# Finished Iteration:  5
# Total Deleted:  1787 	 % Deleted:  0.611986301369863
# Finished Iteration:  6
# Total Deleted:  2012 	 % Deleted:  0.689041095890411
# Finished Iteration:  7
# Total Deleted:  2333 	 % Deleted:  0.798972602739726
# Finished Iteration:  8
# Total Deleted:  2625 	 % Deleted:  0.898972602739726
# Finished Iteration:  9
# Total Deleted:  2896 	 % Deleted:  0.9917808219178083
# Finished Iteration:  10
# Finished Total Iteration:  48
# Diff:  -0.002583333333333382
# Total Deleted:  0 	 % Deleted:  0.0
# Finished Iteration:  0
# Total Deleted:  289 	 % Deleted:  0.09553719008264462
# Finished Iteration:  1
# Total Deleted:  589 	 % Deleted:  0.1947107438016529
# Finished Iteration:  2
# Total Deleted:  894 	 % Deleted:  0.2955371900826446
# Finished Iteration:  3
# Total Deleted:  1168 	 % Deleted:  0.38611570247933885
# Finished Iteration:  4
# Total Deleted:  1488 	 % Deleted:  0.49190082644628097
# Finished Iteration:  5
# Total Deleted:  1801 	 % Deleted:  0.5953719008264463
# Finished Iteration:  6
# Total Deleted:  2125 	 % Deleted:  0.7024793388429752
# Finished Iteration:  7
# Total Deleted:  2438 	 % Deleted:  0.8059504132231405
# Finished Iteration:  8
# Total Deleted:  2684 	 % Deleted:  0.8872727272727273
# Finished Iteration:  9
# Total Deleted:  2998 	 % Deleted:  0.9910743801652893
# Finished Iteration:  10
# Finished Total Iteration:  49
# Diff:  -0.008145833333333297
# Total Deleted:  0 	 % Deleted:  0.0
# Finished Iteration:  0
# Total Deleted:  334 	 % Deleted:  0.10915032679738562
# Finished Iteration:  1
# Total Deleted:  594 	 % Deleted:  0.19411764705882353
# Finished Iteration:  2
# Total Deleted:  903 	 % Deleted:  0.2950980392156863
# Finished Iteration:  3
# Total Deleted:  1234 	 % Deleted:  0.40326797385620916
# Finished Iteration:  4
# Total Deleted:  1496 	 % Deleted:  0.4888888888888889
# Finished Iteration:  5
# Total Deleted:  1830 	 % Deleted:  0.5980392156862745
# Finished Iteration:  6
# Total Deleted:  2128 	 % Deleted:  0.6954248366013072
# Finished Iteration:  7
# Total Deleted:  2456 	 % Deleted:  0.8026143790849674
# Finished Iteration:  8
# Total Deleted:  2753 	 % Deleted:  0.8996732026143791
# Finished Iteration:  9
# Total Deleted:  3023 	 % Deleted:  0.9879084967320262
# Finished Iteration:  10
# Finished Total Iteration:  50

# %%
bias_amts = np.divide(list(range(10,-1,-1)),10)
plt.figure(figsize=(10,7))
plt.errorbar(bias_amts, mean_fidel_maj22, yerr = y_err_fidel_maj22, label = 'Fidelity Majority', color = "red")
plt.errorbar(bias_amts, mean_fidel_min22, yerr = y_err_fidel_min22, label = 'Fidelity Minority', color = "green")
plt.xlabel("Beta Value for Minority")
plt.ylabel("Fidelity")
plt.xlim(1.05, -0.05)
plt.ylim(0.92, 1)
plt.legend()
plt.title("Fidelity Plot")
plt.savefig('repr_inter.jpg')
plt.show()

# %%
random.seed(42)
np.random.seed(42)

eta = 0.4
n = 30000
r = 0.2
num_iters = 50

bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df = \
representation(r = r, n = n, apply_fairness=True,verbose=True, num_iters=num_iters, diff_base = True, inter = True)

df.to_csv('disp_repr_diff_base.csv', index = True)
df_res = pd.DataFrame(np.array([bias_amts, mean_fidel_maj, mean_fidel_min,
                                mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel]).T,
                      columns=['bias_amts', 'mean_fidel_maj', 'mean_fidel_min', 'mean_fidel', 'y_err_fidel_maj', 'y_err_fidel_min', 'y_err_fidel'])
df_res.to_csv(f'fid_repr_diff_base.csv', index = True)
# Out:
# Diff:  0.2084166666666667
# Beta:  1.0
#
# Total Deleted:  0 	 % Deleted:  0.0
# Finished Iteration:  0
# Beta:  0.9
#
# Total Deleted:  298 	 % Deleted:  0.10215975317106617
# Finished Iteration:  1
# Beta:  0.8
#
# Total Deleted:  574 	 % Deleted:  0.19677751114158382
# Finished Iteration:  2
# Beta:  0.7
#
# Total Deleted:  875 	 % Deleted:  0.2999657182036339
# Finished Iteration:  3
# Beta:  0.6
#
# Total Deleted:  1180 	 % Deleted:  0.4045251971203291
# Finished Iteration:  4
# Beta:  0.5
#
# Total Deleted:  1481 	 % Deleted:  0.5077134041823792
# Finished Iteration:  10
# Finished Total Iteration:  50

# %%
bias_amts = np.divide(list(range(10,-1,-1)),10)
plt.figure(figsize=(10,7))
plt.errorbar(bias_amts, mean_fidel_maj23, yerr = y_err_fidel_maj23, label = 'Fidelity Majority', color = "red")
plt.errorbar(bias_amts, mean_fidel_min23, yerr = y_err_fidel_min23, label = 'Fidelity Minority', color = "green")
plt.xlabel("Beta Value for Minority")
plt.ylabel("Fidelity")
plt.xlim(1.05, -0.05)
plt.ylim(0.92, 1)
plt.legend()
plt.title("Fidelity Plot")
plt.savefig('repr_diff_base.jpg')
plt.show()

# %% [markdown]
# ## Label Noise

# %%
def flip(df, eta):
    labels = copy.deepcopy(list(df['outcome'].values))
    #print('Before:', df['outcome_flipped'].value_counts())
    num_flipped = 0
    for i in range(len(labels)):
        if random.uniform(0,1) <= eta:
            labels[i] = 1 if labels[i] == 0 else 0
            num_flipped += 1
    df['outcome_flipped'] = labels
    #print('After:', df['outcome_flipped'].value_counts())
    print('Pos Min Flipped: ', num_flipped, "\tRate: ", num_flipped / len(df))
    return df

def get_noise(df, beta, inter = False, is_init = True):
    df_majority = df[df['cat'] == 1]
    df_minority = df[df['cat'] == 0]
    
    if inter:
        # unfavored group with negative label
        df_minority_negative = df_minority[df_minority['outcome'] == 0.0]

        # unfavored group with positive label (preferred)
        df_minority_positive = df_minority[df_minority['outcome'] == 1.0]
        
        if is_init:
            
            df_undersampled_majog = flip(df_majority, 0.4)
        
            df_undersampled_maj = flip(df_minority_negative, 0.4)

            df_undersampled = flip(df_minority_positive, beta)

            df_concat = pd.concat([df_undersampled_majog,df_undersampled_maj,df_undersampled])
            
        else:
            
            df_total = pd.concat([df_majority, df_minority_negative])
            
            df_undersampled = flip(df_minority_positive, beta)
            
            df_concat = pd.concat([df_total,df_undersampled])
        

        return df_concat.sample(frac=1, random_state = 42) # permute data
    
    else:
        df_undersampled = flip(df_minority, beta)

        # combine undersampled and original favored class to create dataset
        df_concat = pd.concat([df_majority,df_undersampled])

        return df_concat.sample(frac=1, random_state = 42) # permute data

# %%
def label_noise(r, n, apply_fairness = True, verbose = False, num_iters = 10, inter = False, diff_base = False):
    
    total_fidel_maj = []
    total_fidel_min = []
    total_fidel = []
    
    total_disp_bias_train = []
    total_disp_bo_train = []
    total_disp_mitigated_train = []
    
    total_disp_bias_test = []
    total_disp_bo_test = []
    total_disp_mitigated_test = []
    
    for i in range(num_iters):
    
        # 1 to 0 in increments of 0.1
        bias_amts = np.divide(list(range(0,10,1)),20)

        test_maj = []
        test_min = []
        total = []
        
        disp_bias_train = []
        disp_bo_train = []
        disp_mitigated_train = []
        
        disp_bias_test = []
        disp_bo_test = []
        disp_mitigated_test = []
        
        count = 0
        
        if diff_base: 
            #outcome_continuous, df_synthetic = true_label_generation(r=r, eta=eta, n=2*n, maj_means =[0.7,0.7,0.7], is_exploration = True)
            _, df_train = true_label_generation(r=r, eta=eta, n=n, maj_means =[0.7,0.7,0.7], is_exploration = True)
            _, df_test = true_label_generation(r=r, eta=eta, n=n, maj_means =[0.7,0.7,0.7], is_exploration = False)
        else: 
            print('generating train')
            _, df_train = true_label_generation(r=r, eta=eta, n=n, is_exploration = True, inter = inter)
            print('\ngenerating test')
            _, df_test = true_label_generation(r=r, eta=eta, n=n, is_exploration = False, inter = True) 
            #_, df_synthetic = true_label_generation(r=r, eta=eta, n=2*n, is_exploration = False) 
            
        threshold = 0.5
        exact_bo_labels = np.where(outcome_continuous < threshold, 0, 1)
        exact_bo_labels_train = np.array(exact_bo_labels[range(0,n)])
        exact_bo_labels_test = np.array(exact_bo_labels[range(n,len(df_synthetic))])
        
        # split into train and test
        #df_train = df_synthetic.loc[range(0,n), :]
        
        #df_train = get_noise(df_train, 0, inter = True)
        #print("true train")
        #check_groups(df_train)
        
        df_train_bo = get_noise(df_train.copy(), 0.4, inter = inter, is_init = False)
        #print("true train with pos min noise")
        #check_groups(df_train_bo)
        
        X_true, y_true, df_sens_true = transform(df_train_bo, False, True)
        
        # format training data
        #X_true = df_train_transf_bo.iloc[:, :-2].values
        #y_true = df_train_transf_bo.iloc[:, -1].values
        
        #df_test = df_synthetic.loc[range(n, len(df_synthetic)),:]
        #print("test")
        #check_groups(df_test)
        
        #df_train_transf, maj_list, min_list = transform(df_train, True, True)
        
        #df_test = get_noise(df_test, 0, inter = True)
        
        df_test_transf, maj_list, min_list = transform(df_test, True, True)
        
        df_test_maj = df_test_transf.loc[maj_list]
        df_test_min = df_test_transf.loc[min_list]
        
        # format test data
        X_test = df_test_transf.iloc[:, :-2].values
        X_test_maj = df_test_maj.iloc[:, :-2].values
        X_test_min = df_test_min.iloc[:, :-2].values
        y_test = df_test_transf.iloc[:, -1].values
        y_test_maj = df_test_maj.iloc[:, -1].values
        y_test_min = df_test_min.iloc[:, -1].values
        
        sens_attr_test = df_test['cat']
        
        for beta in bias_amts: #[0.4]
            
            if i == 0: print("Beta: ", beta, '\n')

            df_train_copy = df_train.copy()
            
            df_concat = get_noise(df_train_copy, beta, inter, is_init = False) # group-dependent label noise
            #print("biased train")
            #check_groups(df_concat)

            # format data
            X_bias_true, y_bias_true, df_sens = transform(df_concat)
            
            # model trained on biased data
            classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none')
            if beta == 0.4:
                classifier_bias = classifier.fit(X_true, y_true)
            else:
                classifier_bias = classifier.fit(X_bias_true, y_bias_true)
            
            acc = accuracy_score(y_test,classifier_bias.predict(X_test))
            #print(f'Biased classifier:')
            #print(f'     Test accuracy = {acc}')
            
            m = classifier_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            disparity = EqualizedOdds()
            disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            #print(f'     Train error = {error.gamma(classify)[0]}')
            #print(f'     Train disparity = {disparity.gamma(classify).max()}')
            disp_bias_train += [disparity.gamma(classify).max()]

            m = classifier_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            disparity = EqualizedOdds()
            disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            #print(f'     Test error = {error.gamma(classify)[0]}')
            #print(f'     Test disparity = {disparity.gamma(classify).max()}')
            disp_bias_test += [disparity.gamma(classify).max()]
            
            # Learned bayes optimal classifier
            classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none')
            classifier_b = classifier.fit(X_true, y_true)                
            #classifier_b = clone(classifier).fit(X_true, y_true)
            acc = accuracy_score(y_test,classifier_b.predict(X_test))
            #print(f'Learned BO classifier:')
            #print(f'     Test accuracy = {acc}')
            
            m = classifier_b
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            disparity = EqualizedOdds()
            disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            #print(f'     Train error = {error.gamma(classify)[0]}')
            #print(f'     Train disparity = {disparity.gamma(classify).max()}')
            disp_bo_train += [disparity.gamma(classify).max()]

            m = classifier_b
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            disparity = EqualizedOdds()
            disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            #print(f'     Test error = {error.gamma(classify)[0]}')
            #print(f'     Test disparity = {disparity.gamma(classify).max()}')
            disp_bo_test += [disparity.gamma(classify).max()]
            
            
            # Exact BO optimal classifier
            #print(f'Exact BO classifier:')
            acc = accuracy_score(y_test,exact_bo_labels_test)
            #print(f'     Test accuracy = {acc}')
            acc = accuracy_score(y_true,exact_bo_labels_train)
            #print(f'     Train accuracy = {acc}')

            if apply_fairness:
                constraint = EqualizedOdds()
                classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none', fit_intercept = False, max_iter = 200)   

                classifier_mitigated_bias = GridSearch(estimator=classifier,
                                                       constraints=constraint,
                                                       selection_rule='tradeoff_optimization',
                                                       constraint_weight=0.5,
                                                       grid_size=10,
                                                       grid_limit=2.0,
                                                       grid_offset=None,
                                                       grid=None,
                                                       sample_weight_name='sample_weight')
                                                       
                if beta == 0.4:
                    classifier_mitigated_bias.fit(X_true, y_true, sensitive_features = df_sens_true)
                else:
                    classifier_mitigated_bias.fit(X_bias_true, y_bias_true, sensitive_features = df_sens)
                
                acc = accuracy_score(y_test,classifier_mitigated_bias.predict(X_test))
                #print(f'Mitigated bias classifier:')
                #print(f'     Test accuracy = {acc}')
                
                m = classifier_mitigated_bias
                def classify(X): return m.predict(X)
                error = ErrorRate()
                error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
                disparity = EqualizedOdds()
                disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
                #print(f'     Train error = {error.gamma(classify)[0]}')
                #print(f'     Train disparity = {disparity.gamma(classify).max()}')
                disp_mitigated_train += [disparity.gamma(classify).max()]
                
                m = classifier_mitigated_bias
                def classify(X): return m.predict(X)
                error = ErrorRate()
                error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
                disparity = EqualizedOdds()
                disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
                #print(f'     Test error = {error.gamma(classify)[0]}')
                #print(f'     Test disparity = {disparity.gamma(classify).max()}')
                disp_mitigated_test += [disparity.gamma(classify).max()]
                
                # Alternative fidelity of intervention model to no intervention model
                alt_fid_train = accuracy_score(classifier_mitigated_bias.predict(X_bias_true),classifier_bias.predict(X_bias_true))
                alt_fid_test = accuracy_score(classifier_mitigated_bias.predict(X_test),classifier_bias.predict(X_test))
                #print(f'Alternative fidelity of intervention model to no intervention model: train = {alt_fid_train}, test = {alt_fid_test}')
                

            else:
                classifier_mitigated_bias = clone(classifier_bias)
                classifier_mitigated_bias.fit(X_bias_true, y_bias_true)
                
                # NOTE: disparities are the same as for classifier_bias

                
            # Fidelity in this step
            fid = accuracy_score(classifier_mitigated_bias.predict(X_test),classifier_b.predict(X_test))
            #print(f'Test set fidelity of learned BO classifier and mitigated_bias_classifier: {fid}')
            fid = accuracy_score(classifier_mitigated_bias.predict(X_test),exact_bo_labels_test)
            #print(f'Test set fidelity of exact BO classifier and mitigated biased classifier: {fid}')
            fid = accuracy_score(classifier_bias.predict(X_test),classifier_b.predict(X_test))
            #print(f'Test set fidelity of learned BO classifier and biased classifier: {fid}')
            
            # fidelity check
            test_maj += [accuracy_score(classifier_mitigated_bias.predict(X_test_maj), classifier_b.predict(X_test_maj))]
            #print(test_maj)
            test_min += [accuracy_score(classifier_mitigated_bias.predict(X_test_min), classifier_b.predict(X_test_min))]
            #print(test_min)
            total += [accuracy_score(classifier_mitigated_bias.predict(X_test), classifier_b.predict(X_test))]
                
            if verbose:
                print("Finished Iteration: ", count)
                count +=1
        
        #print(f'Fidelity test maj: {test_maj}')
        #print(f'Fidelity test min: {test_maj}')
        
        total_fidel_maj.append(test_maj)
        total_fidel_min.append(test_min)
        total_fidel.append(total)
        
        total_disp_bias_train.append(disp_bias_train)
        total_disp_bo_train.append(disp_bo_train)
        total_disp_mitigated_train.append(disp_mitigated_train)

        total_disp_bias_test.append(disp_bias_test)
        total_disp_bo_test.append(disp_bo_test)
        total_disp_mitigated_test.append(disp_mitigated_test)
        
        if verbose:
                print("Finished Total Iteration: ", i+1)
    
    mean_fidel_maj = np.mean(total_fidel_maj, axis = 0)
    mean_fidel_min = np.mean(total_fidel_min, axis = 0)
    mean_fidel = np.mean(total_fidel, axis = 0)
    
    mean_disp_bias_train = np.mean(total_disp_bias_train, axis = 0)
    mean_disp_bo_train = np.mean(total_disp_bo_train, axis = 0)
    mean_disp_mitigated_train = np.mean(total_disp_mitigated_train, axis = 0)
    
    mean_disp_bias_test = np.mean(total_disp_bias_test, axis = 0)
    mean_disp_bo_test = np.mean(total_disp_bo_test, axis = 0)
    mean_disp_mitigated_test = np.mean(total_disp_mitigated_test, axis = 0)
    
    y_err_fidel_maj = np.std(total_fidel_maj, axis = 0)
    y_err_fidel_min = np.std(total_fidel_min, axis = 0)
    y_err_fidel = np.std(total_fidel, axis = 0)
    
    df = pd.DataFrame({"Biased Train" : mean_disp_bias_train,
                       "BO Train" : mean_disp_bo_train,
                       "Mitigated Train" : mean_disp_mitigated_train,
                       "Biased Test" : mean_disp_bias_test,
                       "BO Test" : mean_disp_bo_test,
                       "Mitigated Test" : mean_disp_mitigated_test})
   
    return bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df

# %%
random.seed(42)
np.random.seed(42)

eta = 0.4
n = 30000
r = 0.2
num_iters = 50

bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df = \
label_noise(r = r, n = n, apply_fairness=True,verbose=True, num_iters=num_iters, diff_base = False, inter = False)

df.to_csv('disp_label_noise_no_inter.csv', index = True)
df_res = pd.DataFrame(np.array([bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel,
                                y_err_fidel_maj, y_err_fidel_min, y_err_fidel]).T,
                      columns=['bias_amts', 'mean_fidel_maj', 'mean_fidel_min', 'mean_fidel', 'y_err_fidel_maj', 'y_err_fidel_min', 'y_err_fidel'])
df_res.to_csv(f'fid_label_noise_no_inter.csv', index = True)
# Out:
# generating train
# Diff:  0.008583333333333332
# Num Flipped Maj:  9594 	Rate:  0.39975
#
# generating test
# Diff:  -0.0010000000000000009
# Pos Min Flipped:  2387 	Rate:  0.3978333333333333
# Beta:  0.0
#
# Pos Min Flipped:  0 	Rate:  0.0
# Finished Iteration:  0
# Beta:  0.05
#
# Pos Min Flipped:  296 	Rate:  0.04933333333333333
# Finished Iteration:  1
# Beta:  0.1
#
# Pos Min Flipped:  618 	Rate:  0.103
# Finished Iteration:  2
# Beta:  0.15
#
# Pos Min Flipped:  863 	Rate:  0.14383333333333334
# Finished Iteration:  3
# Beta:  0.2
#
# Pos Min Flipped:  1234 	Rate:  0.20566666666666666
# Finished Iteration:  4
# Beta:  0.25
#
# Pos Min Flipped:  1496 	Rate:  0.24933333333333332
# Finished Iteration:  5
# Beta:  0.3
#
# Pos Min Flipped:  1837 	Rate:  0.30616666666666664
# Finished Iteration:  6
# Beta:  0.35
#
# Pos Min Flipped:  2165 	Rate:  0.36083333333333334
# Finished Iteration:  7
# Beta:  0.4
#
# Pos Min Flipped:  2404 	Rate:  0.40066666666666667
# Finished Iteration:  8
# Beta:  0.45
#
# Pos Min Flipped:  2732 	Rate:  0.4553333333333333
# Finished Iteration:  9
# Finished Total Iteration:  1
# generating train
# Diff:  0.002958333333333396
# Num Flipped Maj:  9497 	Rate:  0.39570833333333333
#
# generating test
# Diff:  -0.005833333333333357
# Pos Min Flipped:  2331 	Rate:  0.3885
# Pos Min Flipped:  0 	Rate:  0.0
# Finished Iteration:  0
# Pos Min Flipped:  284 	Rate:  0.04733333333333333
# Finished Iteration:  1
# Pos Min Flipped:  606 	Rate:  0.101
# Finished Iteration:  2
# Pos Min Flipped:  910 	Rate:  0.15166666666666667
# Finished Iteration:  3
# Pos Min Flipped:  1189 	Rate:  0.19816666666666666
# Finished Iteration:  4
# Pos Min Flipped:  1479 	Rate:  0.2465
# Finished Iteration:  5
# Pos Min Flipped:  1808 	Rate:  0.30133333333333334
# Finished Iteration:  6
# Pos Min Flipped:  2069 	Rate:  0.3448333333333333
# Finished Iteration:  7
# Pos Min Flipped:  2431 	Rate:  0.4051666666666667
# Finished Iteration:  8
# Pos Min Flipped:  2651 	Rate:  0.44183333333333336
# Finished Iteration:  9
# Finished Total Iteration:  2
# generating train
# Diff:  0.003374999999999906
# Num Flipped Maj:  9473 	Rate:  0.3947083333333333
#
# generating test
# Diff:  -0.007833333333333303
# Pos Min Flipped:  2471 	Rate:  0.41183333333333333
# Pos Min Flipped:  0 	Rate:  0.0
# Finished Iteration:  0
# Pos Min Flipped:  312 	Rate:  0.052
# Finished Iteration:  1
# Pos Min Flipped:  596 	Rate:  0.09933333333333333
# Finished Iteration:  2
# Pos Min Flipped:  916 	Rate:  0.15266666666666667
# Finished Iteration:  3
# Pos Min Flipped:  1145 	Rate:  0.19083333333333333
# Finished Iteration:  4
# Pos Min Flipped:  1532 	Rate:  0.25533333333333336
# Finished Iteration:  5
# Pos Min Flipped:  1778 	Rate:  0.29633333333333334
# Finished Iteration:  6
# Pos Min Flipped:  
# Finished Iteration:  1
# Pos Min Flipped:  597 	Rate:  0.0995
# Finished Iteration:  2
# Pos Min Flipped:  898 	Rate:  0.14966666666666667
# Finished Iteration:  3
# Pos Min Flipped:  1176 	Rate:  0.196
# Finished Iteration:  4
# Pos Min Flipped:  1528 	Rate:  0.25466666666666665
# Finished Iteration:  5
# Pos Min Flipped:  1862 	Rate:  0.31033333333333335
# Finished Iteration:  6
# Pos Min Flipped:  2096 	Rate:  0.34933333333333333
# Finished Iteration:  7
# Pos Min Flipped:  2405 	Rate:  0.4008333333333333
# Finished Iteration:  8
# Pos Min Flipped:  2657 	Rate:  0.44283333333333336
# Finished Iteration:  9
# Finished Total Iteration:  50

# %%
a = 0.5
df_fair = pd.read_csv('fid_label_noise_no_inter.csv')
fig, ax = plt.subplots(figsize=(5,5))
markers, caps, bars = ax.errorbar(df_fair.bias_amts, df_fair.mean_fidel_maj, yerr = df_fair.y_err_fidel_maj, 
                                  label = 'With intervention majority group', color = "blue",
                                  capsize=4, capthick=2)
[bar.set_alpha(a) for bar in bars]
[cap.set_alpha(a) for cap in caps]
markers, caps, bars = ax.errorbar(df_fair.bias_amts, df_fair.mean_fidel_min, yerr = df_fair.y_err_fidel_min, 
                                  label = 'With intervention minority group', color = "blue",
                                      capsize=4, capthick=2, linestyle='--')
plt.ylim(0.35, 1.05)
# Out:
# (0.35, 1.05)

# %%
random.seed(42)
np.random.seed(42)

eta = 0.4
n = 30000
r = 0.2
num_iters = 50

bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df = \
label_noise(r = r, n = n, apply_fairness=True,verbose=True, num_iters=num_iters, diff_base = False, inter = True)

df.to_csv('disp_label_noise_inter.csv', index = True)
df_res = pd.DataFrame(np.array([bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel,
                                y_err_fidel_maj, y_err_fidel_min, y_err_fidel]).T,
                      columns=['bias_amts', 'mean_fidel_maj', 'mean_fidel_min', 'mean_fidel', 'y_err_fidel_maj', 'y_err_fidel_min', 'y_err_fidel'])
df_res.to_csv(f'fid_label_noise_inter.csv', index = True)

# %%
a = 0.5
df_fair = pd.read_csv('fid_label_noise_inter.csv')
fig, ax = plt.subplots(figsize=(5,5))
markers, caps, bars = ax.errorbar(df_fair.bias_amts, df_fair.mean_fidel_maj, yerr = df_fair.y_err_fidel_maj, 
                                  label = 'With intervention majority group', color = "blue",
                                  capsize=4, capthick=2)
[bar.set_alpha(a) for bar in bars]
[cap.set_alpha(a) for cap in caps]
markers, caps, bars = ax.errorbar(df_fair.bias_amts, df_fair.mean_fidel_min, yerr = df_fair.y_err_fidel_min, 
                                  label = 'With intervention minority group', color = "blue",
                                      capsize=4, capthick=2, linestyle='--')
plt.ylim(0.35, 1.05)

# %%
random.seed(42)
np.random.seed(42)

eta = 0.4
n = 30000
r = 0.2
num_iters = 50

bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df = \
label_noise(r = r, n = n, apply_fairness=True,verbose=True, num_iters=num_iters, diff_base = True, inter = True)

df.to_csv('disp_label_noise_diff_base.csv', index = True)
df_res = pd.DataFrame(np.array([bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel]).T, columns=['bias_amts', 'mean_fidel_maj', 'mean_fidel_min', 'mean_fidel', 'y_err_fidel_maj', 'y_err_fidel_min', 'y_err_fidel'])
df_res.to_csv(f'fid_label_noise_diff_base.csv', index = True)

# %%
a = 0.5
df_fair = pd.read_csv('fid_label_noise_diff_base.csv')
fig, ax = plt.subplots(figsize=(5,5))
markers, caps, bars = ax.errorbar(0.4-df_fair.bias_amts, df_fair.mean_fidel_maj, yerr = df_fair.y_err_fidel_maj, 
                                  label = 'With intervention majority group', color = "blue",
                                  capsize=4, capthick=2)
[bar.set_alpha(a) for bar in bars]
[cap.set_alpha(a) for cap in caps]
markers, caps, bars = ax.errorbar(0.4-df_fair.bias_amts, df_fair.mean_fidel_min, yerr = df_fair.y_err_fidel_min, 
                                  label = 'With intervention minority group', color = "blue",
                                      capsize=4, capthick=2, linestyle='--')
plt.ylim(0.35, 1.05)

# %% [markdown]
# ## Feature Noise/Missingness

# %%
def inject_noise_num(df, feature, eta, eps = 1):
    feats = df[feature].values
    #print('Before:', df_synthetic['outcome'].value_counts())
    num_flipped = 0
    for i in range(len(feats)):
        if random.uniform(0,1) <= eta:
            feats[i] = 0
            num_flipped += 1
    df[feature] = feats
    print('Num Flipped: ', num_flipped, "\tRate: ", num_flipped / len(df))
    return df

# measurement bias
def get_biased_data(df, eps, inter):
    df_majority = df[df['cat'] == 1]
    df_minority = df[df['cat'] == 0]
    
    if inter:
    
        # unfavored group with negative label
        df_minority_negative = df_minority[df_minority['outcome'] == 0.0]

        # unfavored group with positive label (preferred)
        df_minority_positive = df_minority[df_minority['outcome'] == 1.0]

        # data frame without positively labeled examples from minority class
        df_total = pd.concat([df_majority, df_minority_negative])

        # under-sampling process
        df_bias = inject_noise_num(df_minority_positive, 'num1', eps)

        # combine undersampled and original favored class to create dataset
        df_concat = pd.concat([df_total,df_bias])
    
    else:
        # under-sampling process
        df_bias = inject_noise_num(df_minority, 'num1', eps)
        # combine undersampled and original favored class to create dataset
        df_concat = pd.concat([df_majority,df_bias])
    
    return df_concat.sample(frac=1, random_state = 42) # permute data

# %%
def measurement(r, n, apply_fairness = True, verbose = False, num_iters = 10, inter = False, diff_base = False):
    
    total_fidel_maj = []
    total_fidel_min = []
    total_fidel = []
    
    total_disp_bias_train = []
    total_disp_bo_train = []
    total_disp_mitigated_train = []
    
    total_disp_bias_test = []
    total_disp_bo_test = []
    total_disp_mitigated_test = []
    
    for i in range(num_iters):
    
        bias_amts = np.divide(list(range(0,11,1)),10)

        test_maj = []
        test_min = []
        total = []
        
        disp_bias_train = []
        disp_bo_train = []
        disp_mitigated_train = []
        
        disp_bias_test = []
        disp_bo_test = []
        disp_mitigated_test = []
        
        count = 0
        
        if diff_base: 
            outcome_continuous, df_synthetic = true_label_generation(r=r, eta=eta, n=2*n, maj_means =[0.7,0.7,0.7])
        else: outcome_continuous, df_synthetic = true_label_generation(r=r, eta=eta, n=2*n)        
        
        threshold = 0.5
        exact_bo_labels = np.where(outcome_continuous < threshold, 0, 1)
        exact_bo_labels_train = np.array(exact_bo_labels[range(0,n)])
        exact_bo_labels_test = np.array(exact_bo_labels[range(n,len(df_synthetic))])
        
        # split into train and test
        df_train = df_synthetic.loc[range(0,n), :]
        
        df_train_transf, maj_list, min_list = transform(df_train, True, True)
        
        df_test = df_synthetic.loc[range(n, len(df_synthetic)),:]
        df_test_transf, maj_list, min_list = transform(df_test, True, False)
        
        df_test_maj = df_test_transf.loc[maj_list]
        df_test_min = df_test_transf.loc[min_list]

        # format training data
        X_true = df_train_transf.iloc[:, :-1].values
        y_true = df_train_transf.iloc[:, -1].values
        
        # format test data
        X_test = df_test_transf.iloc[:, :-1].values
        X_test_maj = df_test_maj.iloc[:, :-1].values
        X_test_min = df_test_min.iloc[:, :-1].values
        y_test = df_test_transf.iloc[:, -1].values
        y_test_maj = df_test_maj.iloc[:, -1].values
        y_test_min = df_test_min.iloc[:, -1].values
        
        sens_attr_test = df_test['cat']
        
        for beta in bias_amts:
            
            if i == 0: print("Beta: ", beta, '\n')

            df_train_copy = df_train.copy()

            df_majority = df_train_copy[df_train_copy['cat'] == 1]
            df_minority = df_train_copy[df_train_copy['cat'] == 0]

            # unfavored group with negative label
            df_minority_negative = df_minority[df_minority['outcome'] == 0.0]

            # unfavored group with positive label (preferred)
            df_minority_positive = df_minority[df_minority['outcome'] == 1.0]

            # data frame without positively labeled examples from minority class
            df_total = pd.concat([df_majority, df_minority_negative])

            # under-sampling process
            df_undersampled = under(df_minority_positive, 1)

            # combine undersampled and original favored class to create dataset
            df_concat1 = pd.concat([df_total,df_undersampled])
            
            df_concat = get_biased_data(df_concat1, beta, inter)

            # format data
            X_bias_true, y_bias_true, df_sens = transform(df_concat)
            
            # model trained on biased data
            classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none')
            classifier_bias = classifier.fit(X_bias_true, y_bias_true)
            
            acc = accuracy_score(y_test,classifier_bias.predict(X_test))
            #print(f'Biased classifier:')
            #print(f'     Test accuracy = {acc}')
            
            m = classifier_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            disparity = EqualizedOdds()
            disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            #print(f'     Train error = {error.gamma(classify)[0]}')
            #print(f'     Train disparity = {disparity.gamma(classify).max()}')
            disp_bias_train += [disparity.gamma(classify).max()]

            m = classifier_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            disparity = EqualizedOdds()
            disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            #print(f'     Test error = {error.gamma(classify)[0]}')
            #print(f'     Test disparity = {disparity.gamma(classify).max()}')
            disp_bias_test += [disparity.gamma(classify).max()]
            
            # Learned bayes optimal classifier
            classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none')
            classifier_b = classifier.fit(X_true, y_true)                
            #classifier_b = clone(classifier).fit(X_true, y_true)
            acc = accuracy_score(y_test,classifier_b.predict(X_test))
            #print(f'Learned BO classifier:')
            #print(f'     Test accuracy = {acc}')
            
            m = classifier_b
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            disparity = EqualizedOdds()
            disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            #print(f'     Train error = {error.gamma(classify)[0]}')
            #print(f'     Train disparity = {disparity.gamma(classify).max()}')
            disp_bo_train += [disparity.gamma(classify).max()]

            m = classifier_b
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            disparity = EqualizedOdds()
            disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            #print(f'     Test error = {error.gamma(classify)[0]}')
            #print(f'     Test disparity = {disparity.gamma(classify).max()}')
            disp_bo_test += [disparity.gamma(classify).max()]
            
            
            # Exact BO optimal classifier
            #print(f'Exact BO classifier:')
            acc = accuracy_score(y_test,exact_bo_labels_test)
            #print(f'     Test accuracy = {acc}')
            acc = accuracy_score(y_true,exact_bo_labels_train)
            #print(f'     Train accuracy = {acc}')

            if apply_fairness:
                constraint = EqualizedOdds()
                classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none', fit_intercept = False, max_iter = 200)   

                classifier_mitigated_bias = GridSearch(estimator=classifier,
                                                       constraints=constraint,
                                                       selection_rule='tradeoff_optimization',
                                                       constraint_weight=0.5,
                                                       grid_size=10,
                                                       grid_limit=2.0,
                                                       grid_offset=None,
                                                       grid=None,
                                                       sample_weight_name='sample_weight')
                                                       
                classifier_mitigated_bias.fit(X_bias_true, y_bias_true, sensitive_features = df_sens)
                
                acc = accuracy_score(y_test,classifier_mitigated_bias.predict(X_test))
                #print(f'Mitigated bias classifier:')
                #print(f'     Test accuracy = {acc}')
                
                m = classifier_mitigated_bias
                def classify(X): return m.predict(X)
                error = ErrorRate()
                error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
                disparity = EqualizedOdds()
                disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
                #print(f'     Train error = {error.gamma(classify)[0]}')
                #print(f'     Train disparity = {disparity.gamma(classify).max()}')
                disp_mitigated_train += [disparity.gamma(classify).max()]
                
                m = classifier_mitigated_bias
                def classify(X): return m.predict(X)
                error = ErrorRate()
                error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
                disparity = EqualizedOdds()
                disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
                #print(f'     Test error = {error.gamma(classify)[0]}')
                #print(f'     Test disparity = {disparity.gamma(classify).max()}')
                disp_mitigated_test += [disparity.gamma(classify).max()]
                
                # Alternative fidelity of intervention model to no intervention model
                alt_fid_train = accuracy_score(classifier_mitigated_bias.predict(X_bias_true),classifier_bias.predict(X_bias_true))
                alt_fid_test = accuracy_score(classifier_mitigated_bias.predict(X_test),classifier_bias.predict(X_test))
                #print(f'Alternative fidelity of intervention model to no intervention model: train = {alt_fid_train}, test = {alt_fid_test}')
                

            else:
                classifier_mitigated_bias = clone(classifier_bias)
                classifier_mitigated_bias.fit(X_bias_true, y_bias_true)
                
                # NOTE: disparities are the same as for classifier_bias

                
            # Fidelity in this step
            fid = accuracy_score(classifier_mitigated_bias.predict(X_test),classifier_b.predict(X_test))
            #print(f'Test set fidelity of learned BO classifier and mitigated_bias_classifier: {fid}')
            fid = accuracy_score(classifier_mitigated_bias.predict(X_test),exact_bo_labels_test)
            #print(f'Test set fidelity of exact BO classifier and mitigated biased classifier: {fid}')
            fid = accuracy_score(classifier_bias.predict(X_test),classifier_b.predict(X_test))
            #print(f'Test set fidelity of learned BO classifier and biased classifier: {fid}')
            
            # fidelity check
            test_maj += [accuracy_score(classifier_mitigated_bias.predict(X_test_maj), classifier_b.predict(X_test_maj))]
            test_min += [accuracy_score(classifier_mitigated_bias.predict(X_test_min), classifier_b.predict(X_test_min))]
            total += [accuracy_score(classifier_mitigated_bias.predict(X_test), classifier_b.predict(X_test))]
                
            if verbose:
                print("Finished Iteration: ", count)
                count +=1
        
        #print(f'Fidelity test maj: {test_maj}')
        #print(f'Fidelity test min: {test_maj}')
        
        total_fidel_maj.append(test_maj)
        total_fidel_min.append(test_min)
        total_fidel.append(total)
        
        total_disp_bias_train.append(disp_bias_train)
        total_disp_bo_train.append(disp_bo_train)
        total_disp_mitigated_train.append(disp_mitigated_train)

        total_disp_bias_test.append(disp_bias_test)
        total_disp_bo_test.append(disp_bo_test)
        total_disp_mitigated_test.append(disp_mitigated_test)
        
        if verbose:
                print("Finished Total Iteration: ", i+1)
    
    mean_fidel_maj = np.mean(total_fidel_maj, axis = 0)
    mean_fidel_min = np.mean(total_fidel_min, axis = 0)
    mean_fidel = np.mean(total_fidel, axis = 0)
    
    mean_disp_bias_train = np.mean(total_disp_bias_train, axis = 0)
    mean_disp_bo_train = np.mean(total_disp_bo_train, axis = 0)
    mean_disp_mitigated_train = np.mean(total_disp_mitigated_train, axis = 0)
    
    mean_disp_bias_test = np.mean(total_disp_bias_test, axis = 0)
    mean_disp_bo_test = np.mean(total_disp_bo_test, axis = 0)
    mean_disp_mitigated_test = np.mean(total_disp_mitigated_test, axis = 0)
    
    y_err_fidel_maj = np.std(total_fidel_maj, axis = 0)
    y_err_fidel_min = np.std(total_fidel_min, axis = 0)
    y_err_fidel = np.std(total_fidel, axis = 0)
    
    df = pd.DataFrame({"Biased Train" : mean_disp_bias_train,
                       "BO Train" : mean_disp_bo_train,
                       "Mitigated Train" : mean_disp_mitigated_train,
                       "Biased Test" : mean_disp_bias_test,
                       "BO Test" : mean_disp_bo_test,
                       "Mitigated Test" : mean_disp_mitigated_test})
   
    return bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
random.seed(42)
np.random.seed(42)

eta = 0.4
n = 30000
r = 0.2
num_iters = 50

bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df = \
measurement(r = r, n = n, apply_fairness=True,verbose=True, num_iters=num_iters, diff_base = False, inter = False)

df.to_csv('disp_featmissing_no_inter.csv', index = True)
df_res = pd.DataFrame(np.array([bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel]).T, columns=['bias_amts', 'mean_fidel_maj', 'mean_fidel_min', 'mean_fidel', 'y_err_fidel_maj', 'y_err_fidel_min', 'y_err_fidel'])
df_res.to_csv(f'fid_featmissing_no_inter.csv', index = True)
# Out:
# Diff:  0.008458333333333345
# Beta:  0.01
#
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  57 	Rate:  0.00962187711006077
# Finished Iteration:  0
# Beta:  0.1
#
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  612 	Rate:  0.10330857528696827
# Finished Iteration:  1
# Beta:  0.2
#
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  1152 	Rate:  0.19446320054017555
# Finished Iteration:  2
# Beta:  0.3
#
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  1818 	Rate:  0.30688723835246456
# Finished Iteration:  3
# Beta:  0.4
#
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  2372 	Rate:  0.400405131667792
# Finished Iteration:  4
# Beta:  0.5
#
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  2970 	Rate:  0.5013504388926401
# Finished Iteration:  5
# Beta:  0.6
#
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  3583 	Rate:  0.6048278190411884
# Finished Iteration:  6
# Beta:  0.7
#
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  4160 	Rate:  0.7022282241728561
# Finished Iteration:  7
# Beta:  0.8
#
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  4732 	Rate:  0.7987846049966238
# Finished Iteration:  8
# Beta:  0.9
#
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  1543 	Rate:  0.5049083769633508
# Finished Iteration:  5
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  1880 	Rate:  0.6151832460732984
# Finished Iteration:  6
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  2100 	Rate:  0.68717277486911
# Finished Iteration:  7
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  2423 	Rate:  0.7928664921465969
# Finished Iteration:  8
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  2777 	Rate:  0.9087041884816754
# Finished Iteration:  9
# Total Deleted:  0 	 % Deleted:  0.0
# Num Flipped:  3056 	Rate:  1.0
# Finished Iteration:  10
# Finished Total Iteration:  50

# %%
# bias_amts = np.divide(list(range(0,11,1)),10)

# plt.figure(figsize=(10,7))
# plt.errorbar(bias_amts, mean_fidel_maj29, yerr = y_err_fidel_maj29, label = 'Fidelity Majority', color = "red")
# plt.errorbar(bias_amts, mean_fidel_min29, yerr = y_err_fidel_min29, label = 'Fidelity Minority', color = "green")
# plt.xlabel("Eta Minority Value")
# plt.ylabel("Fidelity")
# plt.ylim(0.9, 1)
# plt.legend()
# plt.title("Fidelity Plot")
# plt.savefig('featmissing_diff_base.jpg')
# plt.show()

# %%
def diff_base_rates(r, n, verbose = False, num_iters = 10):
    
    beta = 0.6
    bias_amts = [-0.5, -0.4, -0.3, -0.2, -0.1, 0, .1, .2, .3, .4, .5]
    
    total_fidel_maj = []
    total_fidel_min = []
    total_fidel = []
    
    total_disp_bias_train = []
    total_disp_bo_train = []
    total_disp_mitigated_train = []
    
    total_disp_bias_test = []
    total_disp_bo_test = []
    total_disp_mitigated_test = []
    
    vals = [-4, -1.7, -1.1, -0.7, -0.3, 0, 0.35, 0.7, 1.15, 1.75, 4]
    
    for i in range(num_iters):

        test_maj = []
        test_min = []
        total = []
        
        disp_bias_train = []
        disp_bo_train = []
        disp_mitigated_train = []
        
        disp_bias_test = []
        disp_bo_test = []
        disp_mitigated_test = []
        
        count = 0
        
        for diff in vals:
            
            arr = np.ones(3)*diff
            outcome_continuous, df_synthetic = true_label_generation(r=r, eta=eta, n=2*n, maj_means = arr)

            threshold = 0.5
            exact_bo_labels = np.where(outcome_continuous < threshold, 0, 1)
            exact_bo_labels_train = np.array(exact_bo_labels[range(0,n)])
            exact_bo_labels_test = np.array(exact_bo_labels[range(n,len(df_synthetic))])

            # split into train and test
            df_train = df_synthetic.loc[range(0,n), :]

            df_train_transf, maj_list, min_list = transform(df_train, True, True)

            df_test = df_synthetic.loc[range(n, len(df_synthetic)),:]
            df_test_transf, maj_list, min_list = transform(df_test, True, False)

            df_test_maj = df_test_transf.loc[maj_list]
            df_test_min = df_test_transf.loc[min_list]

            # format training data
            X_true = df_train_transf.iloc[:, :-1].values
            y_true = df_train_transf.iloc[:, -1].values

            # format test data
            X_test = df_test_transf.iloc[:, :-1].values
            X_test_maj = df_test_maj.iloc[:, :-1].values
            X_test_min = df_test_min.iloc[:, :-1].values
            y_test = df_test_transf.iloc[:, -1].values
            y_test_maj = df_test_maj.iloc[:, -1].values
            y_test_min = df_test_min.iloc[:, -1].values

            sens_attr_test = df_test['cat']

            df_train_copy = df_train.copy()

            df_majority = df_train_copy[df_train_copy['cat'] == 1]
            df_minority = df_train_copy[df_train_copy['cat'] == 0]

            # unfavored group with negative label
            df_minority_negative = df_minority[df_minority['outcome'] == 0.0]

            # unfavored group with positive label (preferred)
            df_minority_positive = df_minority[df_minority['outcome'] == 1.0]

            # data frame without positively labeled examples from minority class
            df_total = pd.concat([df_majority, df_minority_negative])

            # under-sampling process
            df_undersampled = under(df_minority_positive, beta)

            # combine undersampled and original favored class to create dataset
            df_concat = pd.concat([df_total,df_undersampled]).sample(frac=1, random_state = 42)

            # format data
            X_bias_true, y_bias_true, df_sens = transform(df_concat)

            # model trained on biased data
            classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none')
            classifier_bias = classifier.fit(X_bias_true, y_bias_true)

            acc = accuracy_score(y_test,classifier_bias.predict(X_test))
            #print(f'Biased classifier:')
            #print(f'     Test accuracy = {acc}')

            m = classifier_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            disparity = EqualizedOdds()
            disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            #print(f'     Train error = {error.gamma(classify)[0]}')
            #print(f'     Train disparity = {disparity.gamma(classify).max()}')
            disp_bias_train += [disparity.gamma(classify).max()]

            m = classifier_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            disparity = EqualizedOdds()
            disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            #print(f'     Test error = {error.gamma(classify)[0]}')
            #print(f'     Test disparity = {disparity.gamma(classify).max()}')
            disp_bias_test += [disparity.gamma(classify).max()]

            # Learned bayes optimal classifier
            classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none')
            classifier_b = classifier.fit(X_true, y_true)                
            #classifier_b = clone(classifier).fit(X_true, y_true)
            acc = accuracy_score(y_test,classifier_b.predict(X_test))
            #print(f'Learned BO classifier:')
            #print(f'     Test accuracy = {acc}')

            m = classifier_b
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            disparity = EqualizedOdds()
            disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            #print(f'     Train error = {error.gamma(classify)[0]}')
            #print(f'     Train disparity = {disparity.gamma(classify).max()}')
            disp_bo_train += [disparity.gamma(classify).max()]

            m = classifier_b
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            disparity = EqualizedOdds()
            disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            #print(f'     Test error = {error.gamma(classify)[0]}')
            #print(f'     Test disparity = {disparity.gamma(classify).max()}')
            disp_bo_test += [disparity.gamma(classify).max()]


            # Exact BO optimal classifier
            #print(f'Exact BO classifier:')
            acc = accuracy_score(y_test,exact_bo_labels_test)
            #print(f'     Test accuracy = {acc}')
            acc = accuracy_score(y_true,exact_bo_labels_train)
            #print(f'     Train accuracy = {acc}')

            constraint = EqualizedOdds()
            classifier = LogisticRegression(solver = 'lbfgs', random_state = 42, penalty = 'none', fit_intercept = False, max_iter = 200)   

            classifier_mitigated_bias = GridSearch(estimator=classifier,
                                                   constraints=constraint,
                                                   selection_rule='tradeoff_optimization',
                                                   constraint_weight=0.5,
                                                   grid_size=10,
                                                   grid_limit=2.0,
                                                   grid_offset=None,
                                                   grid=None,
                                                   sample_weight_name='sample_weight')

            classifier_mitigated_bias.fit(X_bias_true, y_bias_true, sensitive_features = df_sens)

            acc = accuracy_score(y_test,classifier_mitigated_bias.predict(X_test))
            #print(f'Mitigated bias classifier:')
            #print(f'     Test accuracy = {acc}')

            m = classifier_mitigated_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            disparity = EqualizedOdds()
            disparity.load_data(X_bias_true, pd.Series(y_bias_true), sensitive_features=df_sens)
            #print(f'     Train error = {error.gamma(classify)[0]}')
            #print(f'     Train disparity = {disparity.gamma(classify).max()}')
            disp_mitigated_train += [disparity.gamma(classify).max()]

            m = classifier_mitigated_bias
            def classify(X): return m.predict(X)
            error = ErrorRate()
            error.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            disparity = EqualizedOdds()
            disparity.load_data(X_test, pd.Series(y_test), sensitive_features=sens_attr_test)
            #print(f'     Test error = {error.gamma(classify)[0]}')
            #print(f'     Test disparity = {disparity.gamma(classify).max()}')
            disp_mitigated_test += [disparity.gamma(classify).max()]

            # Fidelity in this step
            fid = accuracy_score(classifier_mitigated_bias.predict(X_test),classifier_b.predict(X_test))
            #print(f'Test set fidelity of learned BO classifier and mitigated_bias_classifier: {fid}')
            fid = accuracy_score(classifier_mitigated_bias.predict(X_test),exact_bo_labels_test)
            #print(f'Test set fidelity of exact BO classifier and mitigated biased classifier: {fid}')
            fid = accuracy_score(classifier_bias.predict(X_test),classifier_b.predict(X_test))
            #print(f'Test set fidelity of learned BO classifier and biased classifier: {fid}')

            # fidelity check
            test_maj += [accuracy_score(classifier_mitigated_bias.predict(X_test_maj), classifier_b.predict(X_test_maj))]
            test_min += [accuracy_score(classifier_mitigated_bias.predict(X_test_min), classifier_b.predict(X_test_min))]
            total += [accuracy_score(classifier_mitigated_bias.predict(X_test), classifier_b.predict(X_test))]

            if verbose:
                print("Finished Iteration: ", count)
                count +=1
        
        #print(f'Fidelity test maj: {test_maj}')
        #print(f'Fidelity test min: {test_maj}')
        
        total_fidel_maj.append(test_maj)
        total_fidel_min.append(test_min)
        total_fidel.append(total)
        
        total_disp_bias_train.append(disp_bias_train)
        total_disp_bo_train.append(disp_bo_train)
        total_disp_mitigated_train.append(disp_mitigated_train)

        total_disp_bias_test.append(disp_bias_test)
        total_disp_bo_test.append(disp_bo_test)
        total_disp_mitigated_test.append(disp_mitigated_test)
        
        if verbose:
                print("Finished Total Iteration: ", i+1)
    
    mean_fidel_maj = np.mean(total_fidel_maj, axis = 0)
    mean_fidel_min = np.mean(total_fidel_min, axis = 0)
    mean_fidel = np.mean(total_fidel, axis = 0)
    
    mean_disp_bias_train = np.mean(total_disp_bias_train, axis = 0)
    mean_disp_bo_train = np.mean(total_disp_bo_train, axis = 0)
    mean_disp_mitigated_train = np.mean(total_disp_mitigated_train, axis = 0)
    
    mean_disp_bias_test = np.mean(total_disp_bias_test, axis = 0)
    mean_disp_bo_test = np.mean(total_disp_bo_test, axis = 0)
    mean_disp_mitigated_test = np.mean(total_disp_mitigated_test, axis = 0)
    
    y_err_fidel_maj = np.std(total_fidel_maj, axis = 0)
    y_err_fidel_min = np.std(total_fidel_min, axis = 0)
    y_err_fidel = np.std(total_fidel, axis = 0)
    
    df = pd.DataFrame({"Biased Train" : mean_disp_bias_train,
                       "BO Train" : mean_disp_bo_train,
                       "Mitigated Train" : mean_disp_mitigated_train,
                       "Biased Test" : mean_disp_bias_test,
                       "BO Test" : mean_disp_bo_test,
                       "Mitigated Test" : mean_disp_mitigated_test})
   
    return bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

random.seed(42)
np.random.seed(42)

eta = 0.4
n = 30000
r = 0.2
num_iters = 50

bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel, df = \
diff_base_rates(r = r, n = n, verbose=True, num_iters=num_iters)

df.to_csv('disp_diff_base_rates.csv', index = True)
df_res = pd.DataFrame(np.array([bias_amts, mean_fidel_maj, mean_fidel_min, mean_fidel, y_err_fidel_maj, y_err_fidel_min, y_err_fidel]).T, columns=['bias_amts', 'mean_fidel_maj', 'mean_fidel_min', 'mean_fidel', 'y_err_fidel_maj', 'y_err_fidel_min', 'y_err_fidel'])
df_res.to_csv(f'fid_diff_base_rates.csv', index = True)
# Out:
# Diff:  -0.49295833333333333
# Total Deleted:  1159 	 % Deleted:  0.3973260198834419
# Finished Iteration:  0
# Diff:  -0.39225
# Total Deleted:  1202 	 % Deleted:  0.40403361344537814
# Finished Iteration:  1
# Diff:  -0.3004583333333334
# Total Deleted:  1189 	 % Deleted:  0.3903479973736047
# Finished Iteration:  2
# Diff:  -0.20485416666666667
# Total Deleted:  1231 	 % Deleted:  0.40241909120627656
# Finished Iteration:  3
# Diff:  -0.0952708333333333
# Total Deleted:  1222 	 % Deleted:  0.41034251175285424
# Finished Iteration:  4
# Diff:  0.0014583333333333393
# Total Deleted:  1258 	 % Deleted:  0.4212993971868721
# Finished Iteration:  5
# Diff:  0.09785416666666669
# Total Deleted:  1239 	 % Deleted:  0.4076999012833169
# Finished Iteration:  6
# Diff:  0.1993333333333333
# Total Deleted:  1189 	 % Deleted:  0.4018249408583981
# Finished Iteration:  7
# Diff:  0.30108333333333337
# Total Deleted:  1192 	 % Deleted:  0.40161725067385445
# Finished Iteration:  8
# Diff:  0.40564583333333337
# Total Deleted:  1181 	 % Deleted:  0.38469055374592837
# Finished Iteration:  9
# Diff:  0.49364583333333334
# Total Deleted:  1206 	 % Deleted:  0.39801980198019804
# Finished Iteration:  10
# Finished Total Iteration:  1
# Diff:  -0.5011875
# Total Deleted:  1198 	 % Deleted:  0.4129610479145122
# Finished Iteration:  0
# Diff:  -0.39989583333333334
# Total Deleted:  1195 	 % Deleted:  0.39451964344668206
# Finished Iteration:  1
# Diff:  -0.2945
# Total Deleted:  1259 	 % Deleted:  0.41688741721854305
# Finished Iteration:  2
# Diff:  -0.20052083333333331
# Total Deleted:  1158 	 % Deleted:  0.3851014299966744
# Finished Iteration:  3
# Diff:  -0.08320833333333333
# Total Deleted:  1192 	 % Deleted:  0.40324763193504737
# Finished Iteration:  4
# Diff:  -6.250000000007638e-05
# Total Deleted:  1172 	 % Deleted:  0.3893687707641196
# Finished Iteration:  5
# Diff:  0.10693750000000002
# Total Deleted:  1152 	 % Deleted:  0.38971583220568334
# Finished Iteration:  6
# Diff:  0.2016458333333334
# Total Deleted:  1196 	 % Deleted:  0.39161755075311067
# Finished Iteration:  7
# Diff:  0.30237499999999995
# Total Deleted:  1199 	 % Deleted:  0.3884029802397149
# Finished Iteration:  8
# Diff:  0.40366666666666673
# Total Deleted:  1242 	 % Deleted:  0.4085526315789474
# Finished Iteration:  9
# Diff:  0.4910416666666666
# Total Deleted:  1257 	 % Deleted:  0.41663904540934704
# Finished Iteration:  10
# Finished Total Iteration:  2
# Diff:  -0.49604166666666666
# Total Deleted:  1235 	 % Deleted:  0.39941785252263906
# Finished Iteration:  0
# Diff:  -0.3936458333333333
# Total Deleted:  1199 	 % Deleted:  0.3979422502489213
# Finished Iteration:  1
# Diff:  -0.2955208333333333
# Total Deleted:  1232 	 % Deleted:  0.4034053700065488
# Finished Iteration:  2
# Diff:  -0.19808333333333333
# Total Deleted:  1218 	 % Deleted:  0.401980198019802
# Finished Iteration:  3
# Diff:  -0.09604166666666669
# Total Deleted:  1225 	 % Deleted:  0.4116263440860215
# Finished Iteration:  4
# Diff:  -0.0023749999999999605
# Total Deleted:  1162 	 % Deleted:  0.38914936369725384
# Finished Iteration:  5
# Diff:  0.10722916666666665
# Total Deleted:  1175 	 % Deleted:  0.39232053422370616
# Finished Iteration:  6
# Diff:  0.20631250000000007
# Finished Iteration:  4
# Diff:  -0.0001666666666666483
# Total Deleted:  1190 	 % Deleted:  0.4051753489955737
# Finished Iteration:  5
# Diff:  0.10758333333333331
# Total Deleted:  1225 	 % Deleted:  0.4068415808701428
# Finished Iteration:  6
# Diff:  0.19595833333333335
# Total Deleted:  1202 	 % Deleted:  0.3947454844006568
# Finished Iteration:  7
# Diff:  0.3059375
# Total Deleted:  1142 	 % Deleted:  0.37553436369615256
# Finished Iteration:  8
# Diff:  0.40879166666666666
# Total Deleted:  1140 	 % Deleted:  0.39001026342798495
# Finished Iteration:  9
# Diff:  0.5065208333333333
# Total Deleted:  1130 	 % Deleted:  0.38461538461538464
# Finished Iteration:  10
# Finished Total Iteration:  8
# Diff:  -0.498
# Total Deleted:  1237 	 % Deleted:  0.41804663737749237
# Finished Iteration:  0
# Diff:  -0.4101041666666666
# Total Deleted:  1243 	 % Deleted:  0.4107732980832783
# Finished Iteration:  1
# Diff:  -0.2992708333333334
# Total Deleted:  1207 	 % Deleted:  0.41026512576478585
# Finished Iteration:  2
# Diff:  -0.20306250000000003
# Total Deleted:  1207 	 % Deleted:  0.4083220568335589
# Finished Iteration:  3
# Diff:  -0.09083333333333338
# Total Deleted:  1243 	 % Deleted:  0.4100956779940614
# Finished Iteration:  4
# Diff:  -0.005770833333333392
# Total Deleted:  1215 	 % Deleted:  0.4040571998669771
# Finished Iteration:  5
# Diff:  0.10043749999999996
# Total Deleted:  1239 	 % Deleted:  0.4043733681462141
# Finished Iteration:  6
# Diff:  0.19914583333333324
# Total Deleted:  1161 	 % Deleted:  0.39787525702535986
# Finished Iteration:  7
# Diff:  0.3083541666666667
# Total Deleted:  1190 	 % Deleted:  0.39325842696629215
# Finished Iteration:  8
# Diff:  0.4094791666666666
# Total Deleted:  1188 	 % Deleted:  0.39573617588274485
# Finished Iteration:  9
# Diff:  0.49635416666666665
# Total Deleted:  1212 	 % Deleted:  0.40386537820726426
# Finished Iteration:  10
# Finished Total Iteration:  9
# Diff:  -0.5053958333333333
# Total Deleted:  1225 	 % Deleted:  0.40269559500328733
# Finished Iteration:  0
# Diff:  -0.39687500000000003
# Total Deleted:  1205 	 % Deleted:  0.4018006002000667
# Finished Iteration:  1
# Diff:  -0.29708333333333325
# Total Deleted:  1245 	 % Deleted:  0.41555407209612816
# Finished Iteration:  2
# Diff:  -0.20504166666666662
# Total Deleted:  1168 	 % Deleted:  0.3798373983739837
# Finished Iteration:  3
# Diff:  -0.0935833333333333
# Total Deleted:  1202 	 % Deleted:  0.4047138047138047
# Finished Iteration:  4
# Diff:  0.001437500000000036
# Total Deleted:  1197 	 % Deleted:  0.4063136456211813
# Finished Iteration:  5
# Diff:  0.1067083333333333
# Total Deleted:  1212 	 % Deleted:  0.39556135770234985
# Finished Iteration:  6
# Diff:  0.19806249999999992
# Total Deleted:  1237 	 % Deleted:  0.4111000332336324
# Finished Iteration:  7
# Diff:  0.306375
# Total Deleted:  1144 	 % Deleted:  0.39448275862068966
# Finished Iteration:  8
# Diff:  0.413
# Total Deleted:  1251 	 % Deleted:  0.4101639344262295
# Finished Iteration:  9
# Diff:  0.4944791666666667
# Total Deleted:  1150 	 % Deleted:  0.3924914675767918
# Finished Iteration:  10
# Finished Total Iteration:  10
# Diff:  -0.4968125
# Total Deleted:  1211 	 % Deleted:  0.40112620072871813
# Finished Iteration:  0
# Diff:  -0.39491666666666664
# Total Deleted:  1166 	 % Deleted:  0.39863247863247864
# Finished Iteration:  1
# Diff:  -0.301375
# Total Deleted:  1140 	 % Deleted:  0.38190954773869346
# Finished Iteration:  2
# Diff:  -0.2026041666666667
# Total Deleted:  1220 	 % Deleted:  0.410221923335575
# Finished Iteration:  3
# Diff:  -0.084625
# Total Deleted:  1130 	 % Deleted:  0.38540245566166437
# Finished Iteration:  4
# Diff:  -0.0008541666666667114
# Total Deleted:  1218 	 % Deleted:  0.40237859266600595
# Finished Iteration:  5
# Diff:  0.09662499999999996
# Total Deleted:  1227 	 % Deleted:  0.41354903943377147
# Finished Iteration:  6
# Diff:  0.19945833333333335
# Total Deleted:  1195 	 % Deleted:  0.3989983305509182
# Finished Iteration:  7
# Diff:  0.30704166666666666
# Total Deleted:  1138 	 % Deleted:  0.37532981530343007
# Finished Iteration:  8
# Diff:  0.4099375
# Total Deleted:  1185 	 % Deleted:  0.3908311345646438
# Finished Iteration:  9
# Diff:  0.49975
# Total Deleted:  1172 	 % Deleted:  0.3878226340172071
# Finished Iteration:  10
# Finished Total Iteration:  11
# Diff:  -0.5034375
# Total Deleted:  1184 	 % Deleted:  0.39050131926121373
# Finished Iteration:  0
# Diff:  -0.39418749999999997
# Total Deleted:  1185 	 % Deleted:  0.3976510067114094
# Finished Iteration:  1
# Diff:  -0.2951875
# Total Deleted:  1233 	 % Deleted:  0.41796610169491527
# Finished Iteration:  2
# Diff:  -0.19889583333333333
# Total Deleted:  1232 	 % Deleted:  0.4149545301448299
# Finished Iteration:  3
# Diff:  -0.08825
# Total Deleted:  1193 	 % Deleted:  0.3963455149501661
# Finished Iteration:  4
# Diff:  0.007145833333333351
# Total Deleted:  1203 	 % Deleted:  0.401669449081803
# Finished Iteration:  5
# Diff:  0.09356249999999999
# Total Deleted:  1189 	 % Deleted:  0.39060446780551905
# Finished Iteration:  6
# Diff:  0.20381249999999995
# Total Deleted:  1165 	 % Deleted:  0.39558573853989815
# Finished Iteration:  7
# Diff:  0.3127708333333333
# Total Deleted:  1183 	 % Deleted:  0.39420193268910364
# Finished Iteration:  8
# Diff:  0.4048125
# Total Deleted:  1151 	 % Deleted:  0.39056667797760436
# Finished Iteration:  9
# Diff:  0.49914583333333334
# Total Deleted:  1236 	 % Deleted:  0.40631163708086787
# Finished Iteration:  10
# Finished Total Iteration:  12
# Diff:  -0.4895208333333333
# Total Deleted:  1200 	 % Deleted:  0.40053404539385845
# Finished Iteration:  0
# Diff:  -0.39249999999999996
# Total Deleted:  1189 	 % Deleted:  0.3904761904761905
# Finished Iteration:  1
# Diff:  -0.29052083333333334
# Diff:  -0.4919791666666667
# Total Deleted:  1190 	 % Deleted:  0.4028436018957346
# Finished Iteration:  0
# Diff:  -0.40329166666666666
# Total Deleted:  1189 	 % Deleted:  0.3992612491605104
# Finished Iteration:  1
# Diff:  -0.29356249999999995
# Total Deleted:  1189 	 % Deleted:  0.39792503346720215
# Finished Iteration:  2
# Diff:  -0.2082916666666667
# Total Deleted:  1205 	 % Deleted:  0.39821546596166557
# Finished Iteration:  3
# Diff:  -0.08616666666666667
# Total Deleted:  1263 	 % Deleted:  0.4115347018572825
# Finished Iteration:  4
# Diff:  -0.003999999999999948
# Total Deleted:  1211 	 % Deleted:  0.3987487652288443
# Finished Iteration:  5
# Diff:  0.10812500000000003
# Total Deleted:  1169 	 % Deleted:  0.39546684709066304
# Finished Iteration:  6
# Diff:  0.1944583333333333
# Total Deleted:  1230 	 % Deleted:  0.411371237458194
# Finished Iteration:  7
# Diff:  0.31464583333333335
# Total Deleted:  1178 	 % Deleted:  0.38839432904714805
# Finished Iteration:  8
# Diff:  0.4009791666666668
# Total Deleted:  1223 	 % Deleted:  0.400196335078534
# Finished Iteration:  9
# Diff:  0.49764583333333334
# Total Deleted:  1224 	 % Deleted:  0.40556660039761433
# Finished Iteration:  10
# Finished Total Iteration:  18
# Diff:  -0.49683333333333335
# Total Deleted:  1200 	 % Deleted:  0.4012036108324975
# Finished Iteration:  0
# Diff:  -0.3920625
# Total Deleted:  1202 	 % Deleted:  0.3939691904293674
# Finished Iteration:  1
# Diff:  -0.29304166666666664
# Total Deleted:  1209 	 % Deleted:  0.39927344782034346
# Finished Iteration:  2
# Diff:  -0.20624999999999993
# Total Deleted:  1161 	 % Deleted:  0.39209726443769
# Finished Iteration:  3
# Diff:  -0.08541666666666664
# Total Deleted:  1215 	 % Deleted:  0.3875598086124402
# Finished Iteration:  4
# Diff:  -0.00014583333333334503
# Total Deleted:  1160 	 % Deleted:  0.39603960396039606
# Finished Iteration:  5
# Diff:  0.10272916666666665
# Total Deleted:  1192 	 % Deleted:  0.3924925913730655
# Finished Iteration:  6
# Diff:  0.20377083333333335
# Total Deleted:  1143 	 % Deleted:  0.3897033753835663
# Finished Iteration:  7
# Diff:  0.3070625
# Total Deleted:  1173 	 % Deleted:  0.39735772357723576
# Finished Iteration:  8
# Diff:  0.4065625
# Total Deleted:  1196 	 % Deleted:  0.39602649006622515
# Finished Iteration:  9
# Diff:  0.4940833333333333
# Total Deleted:  1202 	 % Deleted:  0.40106773440106774
# Finished Iteration:  10
# Finished Total Iteration:  19
# Diff:  -0.49495833333333333
# Total Deleted:  1183 	 % Deleted:  0.3936772046589018
# Finished Iteration:  0
# Diff:  -0.39608333333333334
# Total Deleted:  1194 	 % Deleted:  0.39341021416803956
# Finished Iteration:  1
# Diff:  -0.2957708333333333
# Total Deleted:  1271 	 % Deleted:  0.40933977455716586
# Finished Iteration:  2
# Diff:  -0.20120833333333327
# Total Deleted:  1264 	 % Deleted:  0.4153795596450871
# Finished Iteration:  3
# Diff:  -0.08574999999999999
# Total Deleted:  1181 	 % Deleted:  0.38861467588022375
# Finished Iteration:  4
# Diff:  0.0020416666666666083
# Total Deleted:  1224 	 % Deleted:  0.4013114754098361
# Finished Iteration:  5
# Diff:  0.10695833333333332
# Total Deleted:  1237 	 % Deleted:  0.40411630186213654
# Finished Iteration:  6
# Diff:  0.19960416666666664
# Total Deleted:  1292 	 % Deleted:  0.43052315894701765
# Finished Iteration:  7
# Diff:  0.30762500000000004
# Total Deleted:  1227 	 % Deleted:  0.4041501976284585
# Finished Iteration:  8
# Diff:  0.40179166666666666
# Total Deleted:  1197 	 % Deleted:  0.3996661101836394
# Finished Iteration:  9
# Diff:  0.4932500000000001
# Total Deleted:  1190 	 % Deleted:  0.397196261682243
# Finished Iteration:  10
# Finished Total Iteration:  20
# Diff:  -0.4913125
# Total Deleted:  1134 	 % Deleted:  0.38689866939611056
# Finished Iteration:  0
# Diff:  -0.4041666666666666
# Total Deleted:  1197 	 % Deleted:  0.403030303030303
# Finished Iteration:  1
# Diff:  -0.2969791666666667
# Total Deleted:  1239 	 % Deleted:  0.4094514210178453
# Finished Iteration:  2
# Diff:  -0.20639583333333333
# Total Deleted:  1157 	 % Deleted:  0.3846409574468085
# Finished Iteration:  3
# Diff:  -0.08956249999999999
# Total Deleted:  1301 	 % Deleted:  0.4258592471358429
# Finished Iteration:  4
# Diff:  0.002020833333333305
# Total Deleted:  1155 	 % Deleted:  0.39325842696629215
# Finished Iteration:  5
# Diff:  0.10164583333333332
# Total Deleted:  1214 	 % Deleted:  0.403188309531717
# Finished Iteration:  6
# Diff:  0.20793749999999994
# Total Deleted:  1205 	 % Deleted:  0.39327676240208875
# Finished Iteration:  7
# Diff:  0.30885416666666665
# Total Deleted:  1216 	 % Deleted:  0.3963494132985658
# Finished Iteration:  8
# Diff:  0.40325
# Total Deleted:  1182 	 % Deleted:  0.4008138351983723
# Finished Iteration:  9
# Diff:  0.49879166666666663
# Total Deleted:  1157 	 % Deleted:  0.39420783645655877
# Finished Iteration:  10
# Finished Total Iteration:  21
# Diff:  -0.5003125
# Total Deleted:  1192 	 % Deleted:  0.3944407677035076
# Finished Iteration:  0
# Diff:  -0.40331249999999996
# Total Deleted:  1209 	 % Deleted:  0.39012584704743464
# Finished Iteration:  1
# Diff:  -0.3033958333333333
# Total Deleted:  1219 	 % Deleted:  0.40961021505376344
# Finished Iteration:  2
# Diff:  -0.203125
# Total Deleted:  1234 	 % Deleted:  0.4043250327653997
# Finished Iteration:  3
# Diff:  -0.08791666666666664
# Total Deleted:  1178 	 % Deleted:  0.3962327615203498
# Finished Iteration:  4
# Diff:  0.0003750000000000142
# Total Deleted:  1208 	 % Deleted:  0.40253248917027656
# Finished Iteration:  5
# Diff:  0.1025208333333334
# Total Deleted:  1168 	 % Deleted:  0.3963352561927384
# Finished Iteration:  6
# Diff:  0.19187500000000002
# Total Deleted:  1279 	 % Deleted:  0.41485566007135904
# Finished Iteration:  7
# Diff:  0.29993749999999997
# Total Deleted:  1221 	 % Deleted:  0.40443855581318316
# Finished Iteration:  8
# Diff:  0.4028541666666666
# Total Deleted:  1141 	 % Deleted:  0.3908872901678657
# Finished Iteration:  9
# Diff:  0.501125
# Total Deleted:  1155 	 % Deleted:  0.3871940998994301
# Finished Iteration:  10
# Finished Total Iteration:  22
# Diff:  -0.49447916666666664
# Total Deleted:  1118 	 % Deleted:  0.38353344768439107
# Finished Iteration:  0
# Diff:  -0.39818749999999997
# Total Deleted:  1252 	 % Deleted:  0.41130091984231276
# Finished Iteration:  1
# Diff:  -0.2886875
# Total Deleted:  1145 	 % Deleted:  0.38630229419703105
# Finished Iteration:  2
# Diff:  -0.1993125
# Total Deleted:  1228 	 % Deleted:  0.41029067824924825
# Finished Iteration:  3
# Diff:  -0.08897916666666672
# Total Deleted:  1196 	 % Deleted:  0.4029649595687331
# Finished Iteration:  4
# Diff:  -0.0024166666666667336
# Total Deleted:  1230 	 % Deleted:  0.4089095744680851
# Finished Iteration:  5
# Diff:  0.10993750000000008
# Total Deleted:  1195 	 % Deleted:  0.39846615538512836
# Finished Iteration:  6
# Diff:  0.1987916666666666
# Total Deleted:  1229 	 % Deleted:  0.413109243697479
# Finished Iteration:  7
# Diff:  0.3063958333333333
# Total Deleted:  1231 	 % Deleted:  0.40453499835688467
# Finished Iteration:  8
# Diff:  0.3933333333333333
# Total Deleted:  1237 	 % Deleted:  0.4033257254646234
# Finished Iteration:  9
# Diff:  0.49850000000000005
# Total Deleted:  1188 	 % Deleted:  0.38508914100486225
# Finished Iteration:  10
# Finished Total Iteration:  23
# Diff:  -0.5006875000000001
# Total Deleted:  1208 	 % Deleted:  0.41426611796982166
# Finished Iteration:  0
# Diff:  -0.39089583333333333
# Total Deleted:  1189 	 % Deleted:  0.4037351443123939
# Finished Iteration:  1
# Diff:  -0.3004166666666667
# Total Deleted:  1205 	 % Deleted:  0.39404839764551997
# Finished Iteration:  2
# Diff:  -0.18485416666666665
# Total Deleted:  1191 	 % Deleted:  0.3984610237537638
# Finished Iteration:  3
# Diff:  -0.08852083333333338
# Total Deleted:  1172 	 % Deleted:  0.39514497639919083
# Finished Iteration:  4
# Diff:  -0.0032291666666666163
# Total Deleted:  1227 	 % Deleted:  0.4094094094094094
# Finished Iteration:  5
# Diff:  0.10185416666666658
# Total Deleted:  1174 	 % Deleted:  0.39264214046822743
# Finished Iteration:  6
# Diff:  0.19958333333333328
# Total Deleted:  1202 	 % Deleted:  0.3994682618810236
# Finished Iteration:  7
# Diff:  0.3098958333333333
# Total Deleted:  1202 	 % Deleted:  0.4008002667555852
# Finished Iteration:  8
# Diff:  0.4065208333333334
# Total Deleted:  1196 	 % Deleted:  0.3921311475409836
# Finished Iteration:  9
# Diff:  0.4968541666666666
# Total Deleted:  1196 	 % Deleted:  0.3991989319092123
# Finished Iteration:  10
# Finished Total Iteration:  24
# Diff:  -0.5030416666666666
# Total Deleted:  1248 	 % Deleted:  0.4103913186451825
# Finished Iteration:  0
# Diff:  -0.3987291666666667
# Total Deleted:  1149 	 % Deleted:  0.3890958347443278
# Finished Iteration:  1
# Diff:  -0.29200000000000004
# Total Deleted:  1176 	 % Deleted:  0.40481927710843374
# Finished Iteration:  2
# Diff:  -0.19691666666666668
# Total Deleted:  1168 	 % Deleted:  0.39286915573494785
# Finished Iteration:  3
# Diff:  -0.08520833333333333
# Total Deleted:  1158 	 % Deleted:  0.3828099173553719
# Finished Iteration:  4
# Diff:  0.004020833333333362
# Total Deleted:  1165 	 % Deleted:  0.39186007399932726
# Finished Iteration:  5
# Diff:  0.10824999999999996
# Total Deleted:  1137 	 % Deleted:  0.3845113290497125
# Finished Iteration:  6
# Diff:  0.19122916666666667
# Total Deleted:  1237 	 % Deleted:  0.41315965263861054
# Finished Iteration:  7
# Diff:  0.3026458333333333
# Total Deleted:  1162 	 % Deleted:  0.3928329952670723
# Finished Iteration:  8
# Diff:  0.4048125
# Total Deleted:  1232 	 % Deleted:  0.41397849462365593
# Finished Iteration:  9
# Diff:  0.4998541666666666
# Total Deleted:  1197 	 % Deleted:  0.40208263352368157
# Finished Iteration:  10
# Finished Total Iteration:  25
# Diff:  -0.5035000000000001
# Total Deleted:  1237 	 % Deleted:  0.4119214119214119
# Finished Iteration:  0
# Diff:  -0.4007083333333334
# Total Deleted:  1207 	 % Deleted:  0.39703947368421055
# Finished Iteration:  1
# Diff:  -0.29514583333333333
# Total Deleted:  1211 	 % Deleted:  0.3973097112860892
# Finished Iteration:  2
# Diff:  -0.20854166666666663
# Total Deleted:  1228 	 % Deleted:  0.410016694490818
# Finished Iteration:  3
# Diff:  -0.09062500000000001
# Total Deleted:  1220 	 % Deleted:  0.4011838211114765
# Finished Iteration:  4
# Diff:  0.007437500000000041
# Total Deleted:  1170 	 % Deleted:  0.3990450204638472
# Finished Iteration:  5
# Diff:  0.10447916666666662
# Total Deleted:  1200 	 % Deleted:  0.4039044092898014
# Finished Iteration:  6
# Diff:  0.19062500000000004
# Total Deleted:  1197 	 % Deleted:  0.4008707300736772
# Finished Iteration:  7
# Diff:  0.30981250000000005
# Total Deleted:  1226 	 % Deleted:  0.40435356200527706
# Finished Iteration:  8
# Diff:  0.39997916666666666
# Total Deleted:  1217 	 % Deleted:  0.40526140526140525
# Finished Iteration:  9
# Diff:  0.49502083333333324
# Total Deleted:  1147 	 % Deleted:  0.39213675213675214
# Finished Iteration:  10
# Finished Total Iteration:  26
# Diff:  -0.4957708333333333
# Total Deleted:  1145 	 % Deleted:  0.3909184021850461
# Finished Iteration:  0
# Diff:  -0.4073333333333333
# Total Deleted:  1241 	 % Deleted:  0.406086387434555
# Finished Iteration:  1
# Diff:  -0.30375
# Total Deleted:  1210 	 % Deleted:  0.40727027936721644
# Finished Iteration:  2
# Diff:  -0.20697916666666671
# Total Deleted:  1220 	 % Deleted:  0.40558510638297873
# Finished Iteration:  3
# Diff:  -0.08962500000000001
# Total Deleted:  1183 	 % Deleted:  0.3938082556591212
# Finished Iteration:  4
# Diff:  -0.0055416666666666115
# Total Deleted:  1142 	 % Deleted:  0.3852901484480432
# Finished Iteration:  5
# Diff:  0.10524999999999995
# Total Deleted:  1194 	 % Deleted:  0.40750853242320817
# Finished Iteration:  6
# Diff:  0.21414583333333337
# Total Deleted:  1164 	 % Deleted:  0.39271255060728744
# Finished Iteration:  7
# Diff:  0.30775
# Total Deleted:  1159 	 % Deleted:  0.39421768707482996
# Finished Iteration:  8
# Diff:  0.401875
# Total Deleted:  1211 	 % Deleted:  0.40788144156281575
# Finished Iteration:  9
# Diff:  0.5023333333333334
# Total Deleted:  1195 	 % Deleted:  0.39767054908485855
# Finished Iteration:  10
# Finished Total Iteration:  27
# Diff:  -0.496
# Total Deleted:  1179 	 % Deleted:  0.393
# Finished Iteration:  0
# Diff:  -0.39922916666666663
# Total Deleted:  1231 	 % Deleted:  0.4108811748998665
# Finished Iteration:  1
# Diff:  -0.2973333333333333
# Total Deleted:  1194 	 % Deleted:  0.40488301119023395
# Finished Iteration:  2
# Diff:  -0.20308333333333334
# Total Deleted:  1206 	 % Deleted:  0.3990734612839179
# Finished Iteration:  3
# Diff:  -0.09041666666666665
# Total Deleted:  1228 	 % Deleted:  0.40368178829717294
# Finished Iteration:  4
# Diff:  0.0015000000000000013
# Total Deleted:  1177 	 % Deleted:  0.3966970003370408
# Finished Iteration:  5
# Diff:  0.09735416666666663
# Total Deleted:  1167 	 % Deleted:  0.4002057613168724
# Finished Iteration:  6
# Diff:  0.19966666666666666
# Total Deleted:  1168 	 % Deleted:  0.39849880586830433
# Finished Iteration:  7
# Diff:  0.3029375000000001
# Total Deleted:  1250 	 % Deleted:  0.4203093476798924
# Finished Iteration:  8
# Diff:  0.408
# Total Deleted:  1203 	 % Deleted:  0.401669449081803
# Finished Iteration:  9
# Diff:  0.4985208333333333
# Total Deleted:  1196 	 % Deleted:  0.39866666666666667
# Finished Iteration:  10
# Finished Total Iteration:  28
# Diff:  -0.5013124999999999
# Total Deleted:  1210 	 % Deleted:  0.40892193308550184
# Finished Iteration:  0
# Diff:  -0.4035416666666667
# Total Deleted:  1171 	 % Deleted:  0.3953409858203916
# Finished Iteration:  1
# Diff:  -0.2935
# Total Deleted:  1179 	 % Deleted:  0.3983108108108108
# Finished Iteration:  2
# Diff:  -0.20912500000000006
# Total Deleted:  1236 	 % Deleted:  0.40537881272548376
# Finished Iteration:  3
# Diff:  -0.08570833333333333
# Total Deleted:  1179 	 % Deleted:  0.4026639344262295
# Finished Iteration:  4
# Diff:  0.008562500000000028
# Total Deleted:  1167 	 % Deleted:  0.3972089857045609
# Finished Iteration:  5
# Diff:  0.10437499999999994
# Total Deleted:  1150 	 % Deleted:  0.3797886393659181
# Finished Iteration:  6
# Diff:  0.20408333333333334
# Total Deleted:  1218 	 % Deleted:  0.3979091800065338
# Finished Iteration:  7
# Diff:  0.3094375
# Total Deleted:  1170 	 % Deleted:  0.38857522417801393
# Finished Iteration:  8
# Diff:  0.39627083333333335
# Total Deleted:  1183 	 % Deleted:  0.3910743801652893
# Finished Iteration:  9
# Diff:  0.5011458333333333
# Total Deleted:  1231 	 % Deleted:  0.41143048128342247
# Finished Iteration:  3
# Diff:  -0.08956249999999999
# Total Deleted:  1160 	 % Deleted:  0.39496084439904666
# Finished Iteration:  4
# Diff:  -0.002833333333333299
# Total Deleted:  1228 	 % Deleted:  0.4089244089244089
# Finished Iteration:  5
# Diff:  0.09297916666666672
# Total Deleted:  1232 	 % Deleted:  0.4049967126890204
# Finished Iteration:  6
# Diff:  0.1898333333333333
# Total Deleted:  1210 	 % Deleted:  0.4090601757944557
# Finished Iteration:  7
# Diff:  0.3053541666666667
# Total Deleted:  1229 	 % Deleted:  0.40401051939513477
# Finished Iteration:  8
# Diff:  0.40543749999999995
# Total Deleted:  1221 	 % Deleted:  0.402970297029703
# Finished Iteration:  9
# Diff:  0.5019791666666666
# Total Deleted:  1135 	 % Deleted:  0.3913793103448276
# Finished Iteration:  10
# Finished Total Iteration:  32
# Diff:  -0.4981041666666667
# Total Deleted:  1195 	 % Deleted:  0.3956953642384106
# Finished Iteration:  0
# Diff:  -0.3982708333333333
# Total Deleted:  1196 	 % Deleted:  0.4037812288993923
# Finished Iteration:  1
# Diff:  -0.29460416666666667
# Total Deleted:  1168 	 % Deleted:  0.3953960731211916
# Finished Iteration:  2
# Diff:  -0.20085416666666667
# Total Deleted:  1284 	 % Deleted:  0.42572944297082227
# Finished Iteration:  3
# Diff:  -0.0909166666666667
# Total Deleted:  1222 	 % Deleted:  0.40828600066822585
# Finished Iteration:  4
# Diff:  0.007166666666666599
# Total Deleted:  1179 	 % Deleted:  0.4022517911975435
# Finished Iteration:  5
# Diff:  0.10379166666666673
# Total Deleted:  1169 	 % Deleted:  0.39546684709066304
# Finished Iteration:  6
# Diff:  0.19495833333333323
# Total Deleted:  1188 	 % Deleted:  0.4123568205484207
# Finished Iteration:  7
# Diff:  0.30675
# Total Deleted:  1198 	 % Deleted:  0.40080294412847106
# Finished Iteration:  8
# Diff:  0.4083125
# Total Deleted:  1222 	 % Deleted:  0.40938023450586264
# Finished Iteration:  9
# Diff:  0.5049583333333333
# Total Deleted:  1175 	 % Deleted:  0.399252463472647
# Finished Iteration:  10
# Finished Total Iteration:  33
# Diff:  -0.4955625
# Total Deleted:  1251 	 % Deleted:  0.4134170522141441
# Finished Iteration:  0
# Diff:  -0.3921458333333333
# Total Deleted:  1211 	 % Deleted:  0.40719569603227973
# Finished Iteration:  1
# Diff:  -0.2875625
# Total Deleted:  1187 	 % Deleted:  0.3951398135818908
# Finished Iteration:  2
# Diff:  -0.19606249999999997
# Total Deleted:  1220 	 % Deleted:  0.3993453355155483
# Finished Iteration:  3
# Diff:  -0.09033333333333338
# Total Deleted:  1237 	 % Deleted:  0.4117842876165113
# Finished Iteration:  4
# Diff:  -0.008187500000000014
# Total Deleted:  1146 	 % Deleted:  0.3882113821138211
# Finished Iteration:  5
# Diff:  0.09647916666666667
# Total Deleted:  1208 	 % Deleted:  0.4015957446808511
# Finished Iteration:  6
# Diff:  0.2077708333333333
# Total Deleted:  1174 	 % Deleted:  0.3921175684702739
# Finished Iteration:  7
# Diff:  0.30947916666666664
# Total Deleted:  1187 	 % Deleted:  0.3972556894243641
# Finished Iteration:  1
# Diff:  -0.29962500000000003
# Total Deleted:  1207 	 % Deleted:  0.40126329787234044
# Finished Iteration:  2
# Diff:  -0.20360416666666664
# Total Deleted:  1199 	 % Deleted:  0.40370370370370373
# Finished Iteration:  3
# Diff:  -0.08662500000000001
# Total Deleted:  1172 	 % Deleted:  0.3971535072856659
# Finished Iteration:  4
# Diff:  0.004854166666666659
# Total Deleted:  1255 	 % Deleted:  0.4099967330937602
# Finished Iteration:  5
# Diff:  0.10033333333333339
# Total Deleted:  1186 	 % Deleted:  0.39454424484364603
# Finished Iteration:  6
# Diff:  0.19810416666666664
# Total Deleted:  1170 	 % Deleted:  0.40013679890560877
# Finished Iteration:  7
# Diff:  0.3007291666666666
# Total Deleted:  1232 	 % Deleted:  0.4041994750656168
# Finished Iteration:  8
# Diff:  0.4104791666666666
# Total Deleted:  1185 	 % Deleted:  0.4007439972945553
# Finished Iteration:  9
# Diff:  0.5080416666666666
# Total Deleted:  1177 	 % Deleted:  0.3920719520319787
# Finished Iteration:  10
# Finished Total Iteration:  37
# Diff:  -0.4912916666666667
# Total Deleted:  1220 	 % Deleted:  0.3994760969220694
# Finished Iteration:  0
# Diff:  -0.395875
# Total Deleted:  1187 	 % Deleted:  0.3918785077583361
# Finished Iteration:  1
# Diff:  -0.30445833333333333
# Total Deleted:  1190 	 % Deleted:  0.4028436018957346
# Finished Iteration:  2
# Diff:  -0.20685416666666662
# Total Deleted:  1185 	 % Deleted:  0.39329571855293727
# Finished Iteration:  3
# Diff:  -0.0967291666666667
# Total Deleted:  1211 	 % Deleted:  0.40746971736204574
# Finished Iteration:  4
# Diff:  -0.018083333333333285
# Total Deleted:  1177 	 % Deleted:  0.3920719520319787
# Finished Iteration:  5
# Diff:  0.10310416666666672
# Total Deleted:  1255 	 % Deleted:  0.4065435698088759
# Finished Iteration:  6
# Diff:  0.19872916666666662
# Total Deleted:  1200 	 % Deleted:  0.40106951871657753
# Finished Iteration:  7
# Diff:  0.30985416666666665
# Total Deleted:  1164 	 % Deleted:  0.39659284497444636
# Finished Iteration:  8
# Diff:  0.40731249999999997
# Total Deleted:  1169 	 % Deleted:  0.3977543382102756
# Finished Iteration:  9
# Diff:  0.4927083333333333
# Total Deleted:  1214 	 % Deleted:  0.40105715229600264
# Finished Iteration:  10
# Finished Total Iteration:  38
# Diff:  -0.49443750000000003
# Total Deleted:  1241 	 % Deleted:  0.41491140086927447
# Finished Iteration:  0
# Diff:  -0.39089583333333333
# Total Deleted:  1218 	 % Deleted:  0.41162554917201755
# Finished Iteration:  1
# Diff:  -0.300875
# Total Deleted:  1181 	 % Deleted:  0.4029341521664961
# Finished Iteration:  2
# Diff:  -0.20066666666666666
# Total Deleted:  1207 	 % Deleted:  0.40612382234185734
# Finished Iteration:  3
# Diff:  -0.09641666666666665
# Total Deleted:  1243 	 % Deleted:  0.4132313829787234
# Finished Iteration:  4
# Diff:  0.0014999999999999458
# Total Deleted:  1199 	 % Deleted:  0.3992673992673993
# Finished Iteration:  5
# Diff:  0.10974999999999996
# Total Deleted:  1244 	 % Deleted:  0.40534376018246987
# Finished Iteration:  6
# Diff:  0.20827083333333335
# Total Deleted:  1184 	 % Deleted:  0.3937479215164616
# Finished Iteration:  7
# Diff:  0.3085625
# Total Deleted:  1157 	 % Deleted:  0.3980048159614723
# Finished Iteration:  8
# Diff:  0.40189583333333334
# Total Deleted:  1179 	 % Deleted:  0.3927381745502998
# Finished Iteration:  9
# Diff:  0.4967708333333333
# Total Deleted:  1188 	 % Deleted:  0.3987915407854985
# Finished Iteration:  10
# Finished Total Iteration:  39
# Diff:  -0.5088958333333333
# Total Deleted:  1221 	 % Deleted:  0.3981089012063906
# Finished Iteration:  0
# Diff:  -0.39770833333333333
# Total Deleted:  1170 	 % Deleted:  0.3922225947033188
# Finished Iteration:  1
# Diff:  -0.28983333333333333
# Total Deleted:  1212 	 % Deleted:  0.40521564694082246
# Finished Iteration:  2
# Diff:  -0.2029791666666667
# Total Deleted:  1236 	 % Deleted:  0.40631163708086787
# Finished Iteration:  3
# Diff:  -0.08195833333333336
# Total Deleted:  1209 	 % Deleted:  0.39278752436647174
# Finished Iteration:  4
# Diff:  -0.010687500000000016
# Total Deleted:  1227 	 % Deleted:  0.40683023872679047
# Finished Iteration:  5
# Diff:  0.10429166666666667
# Total Deleted:  1174 	 % Deleted:  0.3981010512037979
# Finished Iteration:  6
# Diff:  0.20210416666666664
# Total Deleted:  1253 	 % Deleted:  0.408675799086758
# Finished Iteration:  7
# Diff:  0.3104791666666667
# Total Deleted:  1111 	 % Deleted:  0.37982905982905985
# Finished Iteration:  8
# Diff:  0.4107916666666666
# Total Deleted:  1214 	 % Deleted:  0.4038589487691284
# Finished Iteration:  9
# Diff:  0.5000625000000001
# Total Deleted:  1212 	 % Deleted:  0.400396432111001
# Finished Iteration:  10
# Finished Total Iteration:  40
# Diff:  -0.5005833333333334
# Total Deleted:  1187 	 % Deleted:  0.393176548526002
# Finished Iteration:  0
# Diff:  -0.397125
# Total Deleted:  1201 	 % Deleted:  0.39993339993339994
# Finished Iteration:  1
# Diff:  -0.2936875
# Total Deleted:  1258 	 % Deleted:  0.40580645161290324
# Finished Iteration:  2
# Diff:  -0.2069583333333334
# Total Deleted:  1263 	 % Deleted:  0.4140983606557377
# Finished Iteration:  3
# Diff:  -0.08808333333333329
# Total Deleted:  1173 	 % Deleted:  0.3887968180311568
# Finished Iteration:  4
# Diff:  -0.003750000000000031
# Total Deleted:  1206 	 % Deleted:  0.4009308510638298
# Finished Iteration:  5
# Diff:  0.10533333333333333
# Total Deleted:  1183 	 % Deleted:  0.40183423913043476
# Finished Iteration:  6
# Diff:  0.2079583333333333
# Total Deleted:  1231 	 % Deleted:  0.4032099574189322
# Finished Iteration:  7
# Diff:  0.3073125
# Total Deleted:  1165 	 % Deleted:  0.3927848954821308
# Finished Iteration:  8
# Diff:  0.40497916666666667
# Total Deleted:  1203 	 % Deleted:  0.39650626235992087
# Finished Iteration:  9
# Diff:  0.4906041666666666
# Total Deleted:  1203 	 % Deleted:  0.40126751167444963
# Finished Iteration:  10
# Finished Total Iteration:  41
# Diff:  -0.5058541666666666
# Total Deleted:  1184 	 % Deleted:  0.39758226997985224
# Finished Iteration:  0
# Diff:  -0.39620833333333333
# Total Deleted:  1212 	 % Deleted:  0.40185676392572944
# Finished Iteration:  1
# Diff:  -0.29858333333333337
# Total Deleted:  1204 	 % Deleted:  0.39359267734553777
# Finished Iteration:  2
# Diff:  -0.20239583333333333
# Total Deleted:  1179 	 % Deleted:  0.39091511936339524
# Finished Iteration:  3
# Diff:  -0.0897916666666666
# Total Deleted:  1133 	 % Deleted:  0.38471986417657045
# Finished Iteration:  4
# Diff:  -0.004958333333333287
# Total Deleted:  1179 	 % Deleted:  0.3967025572005384
# Finished Iteration:  5
# Diff:  0.11195833333333327
# Total Deleted:  1219 	 % Deleted:  0.40947262344642255
# Finished Iteration:  6
# Diff:  0.19093749999999998
# Total Deleted:  1231 	 % Deleted:  0.39941596365996107
# Finished Iteration:  7
# Diff:  0.30252083333333335
# Total Deleted:  1122 	 % Deleted:  0.38306589279617614
# Finished Iteration:  8
# Diff:  0.4054791666666666
# Total Deleted:  1153 	 % Deleted:  0.38471805138471804
# Finished Iteration:  9
# Diff:  0.49477083333333327
# Total Deleted:  1178 	 % Deleted:  0.396900269541779
# Finished Iteration:  10
# Finished Total Iteration:  42
# Diff:  -0.5001041666666667
# Total Deleted:  1195 	 % Deleted:  0.3938694792353329
# Finished Iteration:  0
# Diff:  -0.3964375
# Total Deleted:  1241 	 % Deleted:  0.40648542417294464
# Finished Iteration:  1
# Diff:  -0.3033333333333333
# Total Deleted:  1216 	 % Deleted:  0.3997370151216305
# Finished Iteration:  2
# Diff:  -0.1964583333333333
# Total Deleted:  1158 	 % Deleted:  0.39068825910931176
# Finished Iteration:  3
# Diff:  -0.07933333333333331
# Total Deleted:  1250 	 % Deleted:  0.41118421052631576
# Finished Iteration:  4
# Diff:  -0.00122916666666667
# Total Deleted:  1212 	 % Deleted:  0.40279162512462613
# Finished Iteration:  5
# Diff:  0.10077083333333337
# Total Deleted:  1203 	 % Deleted:  0.39121951219512197
# Finished Iteration:  6
# Diff:  0.20058333333333334
# Total Deleted:  1207 	 % Deleted:  0.39664804469273746
# Finished Iteration:  7
# Diff:  0.30637499999999995
# Total Deleted:  1218 	 % Deleted:  0.40105367138623643
# Finished Iteration:  8
# Diff:  0.4086875
# Total Deleted:  1184 	 % Deleted:  0.3947982660886962
# Finished Iteration:  9
# Diff:  0.49975
# Total Deleted:  1190 	 % Deleted:  0.40655961735565427
# Finished Iteration:  10
# Finished Total Iteration:  43
# Diff:  -0.4991458333333333
# Total Deleted:  1184 	 % Deleted:  0.39585422935473086
# Finished Iteration:  0
# Diff:  -0.39329166666666665
# Total Deleted:  1192 	 % Deleted:  0.39693639693639693
# Finished Iteration:  1
# Diff:  -0.300875
# Total Deleted:  1162 	 % Deleted:  0.3960463531015678
# Finished Iteration:  2
# Diff:  -0.2036041666666667
# Total Deleted:  1261 	 % Deleted:  0.41466622821440313
# Finished Iteration:  3
# Diff:  -0.08091666666666669
# Total Deleted:  1233 	 % Deleted:  0.4123745819397993
# Finished Iteration:  4
# Diff:  0.007833333333333359
# Total Deleted:  1297 	 % Deleted:  0.418252176717188
# Finished Iteration:  5
# Diff:  0.11581249999999998
# Total Deleted:  1165 	 % Deleted:  0.3882039320226591
# Finished Iteration:  6
# Diff:  0.20906250000000004
# Total Deleted:  1197 	 % Deleted:  0.4121900826446281
# Finished Iteration:  7
# Diff:  0.30241666666666667
# Total Deleted:  1226 	 % Deleted:  0.4044869679973606
# Finished Iteration:  8
# Diff:  0.41022916666666664
# Total Deleted:  1217 	 % Deleted:  0.4013852242744063
# Finished Iteration:  9
# Diff:  0.5037708333333333
# Total Deleted:  1198 	 % Deleted:  0.4080381471389646
# Finished Iteration:  10
# Finished Total Iteration:  44
# Diff:  -0.5032083333333333
# Total Deleted:  1159 	 % Deleted:  0.39010434197239985
# Finished Iteration:  0
# Diff:  -0.39629166666666665
# Total Deleted:  1248 	 % Deleted:  0.416
# Finished Iteration:  1
# Diff:  -0.3025833333333333
# Total Deleted:  1154 	 % Deleted:  0.3868588669125042
# Finished Iteration:  2
# Diff:  -0.18991666666666668
# Total Deleted:  1283 	 % Deleted:  0.4199672667757774
# Finished Iteration:  3
# Diff:  -0.08333333333333331
# Total Deleted:  1175 	 % Deleted:  0.3961564396493594
# Finished Iteration:  4
# Diff:  -0.0001875000000000071
# Total Deleted:  1206 	 % Deleted:  0.3933463796477495
# Finished Iteration:  5
# Diff:  0.09737499999999999
# Total Deleted:  1177 	 % Deleted:  0.38896232650363516
# Finished Iteration:  6
# Diff:  0.204625
# Total Deleted:  1204 	 % Deleted:  0.40511440107671604
# Finished Iteration:  7
# Diff:  0.3000625
# Total Deleted:  1172 	 % Deleted:  0.3882080158993044
# Finished Iteration:  8
# Diff:  0.40725
# Total Deleted:  1229 	 % Deleted:  0.4012406137773425
# Finished Iteration:  9
# Diff:  0.5073749999999999
# Total Deleted:  1209 	 % Deleted:  0.39
# Finished Iteration:  10
# Finished Total Iteration:  45
# Diff:  -0.49825
# Total Deleted:  1216 	 % Deleted:  0.40198347107438015
# Finished Iteration:  0
# Diff:  -0.4027708333333333
# Total Deleted:  1206 	 % Deleted:  0.4148606811145511
# Finished Iteration:  1
# Diff:  -0.2867708333333333
# Total Deleted:  1240 	 % Deleted:  0.4122340425531915
# Finished Iteration:  2
# Diff:  -0.19904166666666667
# Total Deleted:  1190 	 % Deleted:  0.39825970548862116
# Finished Iteration:  3
# Diff:  -0.08720833333333333
# Total Deleted:  1200 	 % Deleted:  0.3970880211780278
# Finished Iteration:  4
# Diff:  0.0068749999999999645
# Total Deleted:  1234 	 % Deleted:  0.4084740152267461
# Finished Iteration:  5
# Diff:  0.09966666666666668
# Total Deleted:  1188 	 % Deleted:  0.3963963963963964
# Finished Iteration:  6
# Diff:  0.197125
# Total Deleted:  1170 	 % Deleted:  0.399453738477296
# Finished Iteration:  7
# Diff:  0.3033541666666667
# Total Deleted:  1175 	 % Deleted:  0.40061370610296626
# Finished Iteration:  8
# Diff:  0.404625
# Total Deleted:  1247 	 % Deleted:  0.4095238095238095
# Finished Iteration:  9
# Diff:  0.499
# Total Deleted:  1175 	 % Deleted:  0.39722785665990534
# Finished Iteration:  10
# Finished Total Iteration:  46
# Diff:  -0.49345833333333333
# Total Deleted:  1170 	 % Deleted:  0.39248574303924855
# Finished Iteration:  0
# Diff:  -0.40497916666666667
# Total Deleted:  1167 	 % Deleted:  0.389
# Finished Iteration:  1
# Diff:  -0.30266666666666664
# Total Deleted:  1169 	 % Deleted:  0.3883720930232558
# Finished Iteration:  2
# Diff:  -0.20672916666666669
# Total Deleted:  1228 	 % Deleted:  0.40487965710517637
# Finished Iteration:  3
# Diff:  -0.10066666666666663
# Total Deleted:  1143 	 % Deleted:  0.393324156916724
# Finished Iteration:  4
# Diff:  0.005333333333333357
# Total Deleted:  1196 	 % Deleted:  0.3956334766787959
# Finished Iteration:  5
# Diff:  0.09947916666666667
# Total Deleted:  1199 	 % Deleted:  0.39557901682613
# Finished Iteration:  6
# Diff:  0.2014375
# Total Deleted:  1133 	 % Deleted:  0.37943737441393166
# Finished Iteration:  7
# Diff:  0.30666666666666675
# Total Deleted:  1215 	 % Deleted:  0.41284403669724773
# Finished Iteration:  8
# Diff:  0.40202083333333327
# Total Deleted:  1179 	 % Deleted:  0.4007477906186268
# Finished Iteration:  9
# Diff:  0.49068750000000005
# Total Deleted:  1164 	 % Deleted:  0.3921832884097035
# Finished Iteration:  10
# Finished Total Iteration:  47
# Diff:  -0.49225
# Total Deleted:  1189 	 % Deleted:  0.39939536446086665
# Finished Iteration:  0
# Diff:  -0.4047291666666667
# Total Deleted:  1211 	 % Deleted:  0.3979625369700953
# Finished Iteration:  1
# Diff:  -0.2937708333333333
# Total Deleted:  1230 	 % Deleted:  0.4120603015075377
# Finished Iteration:  2
# Diff:  -0.2040833333333334
# Total Deleted:  1219 	 % Deleted:  0.40244305051172
# Finished Iteration:  3
# Diff:  -0.08635416666666668
# Total Deleted:  1187 	 % Deleted:  0.39422118897376285
# Finished Iteration:  4
# Diff:  0.012270833333333342
# Total Deleted:  1200 	 % Deleted:  0.3961703532518983
# Finished Iteration:  5
# Diff:  0.10216666666666663
# Total Deleted:  1214 	 % Deleted:  0.4
# Finished Iteration:  6
# Diff:  0.1999791666666666
# Total Deleted:  1172 	 % Deleted:  0.39315665883931566
# Finished Iteration:  7
# Diff:  0.3047291666666667
# Total Deleted:  1173 	 % Deleted:  0.3942857142857143
# Finished Iteration:  8
# Diff:  0.4047708333333333
# Total Deleted:  1176 	 % Deleted:  0.399592252803262
# Finished Iteration:  9
# Diff:  0.49879166666666663
# Total Deleted:  1216 	 % Deleted:  0.4025157232704403
# Finished Iteration:  10
# Finished Total Iteration:  48
# Diff:  -0.49516666666666664
# Total Deleted:  1143 	 % Deleted:  0.3858879135719109
# Finished Iteration:  0
# Diff:  -0.39849999999999997
# Total Deleted:  1232 	 % Deleted:  0.4024828487422411
# Finished Iteration:  1
# Diff:  -0.2997916666666667
# Total Deleted:  1181 	 % Deleted:  0.3927502494180246
# Finished Iteration:  2
# Diff:  -0.20502083333333337
# Total Deleted:  1189 	 % Deleted:  0.3917627677100494
# Finished Iteration:  3
# Diff:  -0.08754166666666663
# Total Deleted:  1168 	 % Deleted:  0.3971438286297178
# Finished Iteration:  4
# Diff:  0.006312499999999999
# Total Deleted:  1265 	 % Deleted:  0.4177675033025099
# Finished Iteration:  5
# Diff:  0.11229166666666662
# Total Deleted:  1143 	 % Deleted:  0.37935612346498504
# Finished Iteration:  6
# Diff:  0.21595833333333336
# Total Deleted:  1315 	 % Deleted:  0.43514228987425546
# Finished Iteration:  7
# Diff:  0.3105208333333333
# Total Deleted:  1214 	 % Deleted:  0.3951822916666667
# Finished Iteration:  8
# Diff:  0.4036875
# Total Deleted:  1200 	 % Deleted:  0.39748261013580655
# Finished Iteration:  9
# Diff:  0.49275
# Total Deleted:  1203 	 % Deleted:  0.39572368421052634
# Finished Iteration:  10
# Finished Total Iteration:  49
# Diff:  -0.5011249999999999
# Total Deleted:  1229 	 % Deleted:  0.4107620320855615
# Finished Iteration:  0
# Diff:  -0.3978333333333333
# Total Deleted:  1198 	 % Deleted:  0.40391099123398516
# Finished Iteration:  1
# Diff:  -0.2931041666666667
# Total Deleted:  1224 	 % Deleted:  0.40786404531822723
# Finished Iteration:  2
# Diff:  -0.20239583333333333
# Total Deleted:  1304 	 % Deleted:  0.42517117704597324
# Finished Iteration:  3
# Diff:  -0.08599999999999997
# Total Deleted:  1164 	 % Deleted:  0.388
# Finished Iteration:  4
# Diff:  0.00187499999999996
# Total Deleted:  1265 	 % Deleted:  0.4099157485418017
# Finished Iteration:  5
# Diff:  0.10306250000000006
# Total Deleted:  1202 	 % Deleted:  0.40787241262300644
# Finished Iteration:  6
# Diff:  0.19399999999999995
# Total Deleted:  1199 	 % Deleted:  0.40020026702269695
# Finished Iteration:  7
# Diff:  0.31168750000000006
# Total Deleted:  1222 	 % Deleted:  0.39843495272253016
# Finished Iteration:  8
# Diff:  0.4008333333333334
# Total Deleted:  1210 	 % Deleted:  0.3872
# Finished Iteration:  9
# Diff:  0.49639583333333337
# Total Deleted:  1227 	 % Deleted:  0.40203145478374835
# Finished Iteration:  10
# Finished Total Iteration:  50

# %%
bias_amts = [-0.5, -0.4, -0.3, -0.2, -0.1, 0, .1, .2, .3, .4, .5]
plt.figure(figsize=(10,7))
plt.errorbar(bias_amts, mean_fidel_maj, yerr = y_err_fidel_maj, label = 'Fidelity Majority', color = "red")
plt.errorbar(bias_amts, mean_fidel_min, yerr = y_err_fidel_min, label = 'Fidelity Minority', color = "green")
plt.xlabel("Difference in Proportion of Positive Labels (Majority - Minority)")
plt.ylabel("Fidelity")
#plt.xlim(-0.4, 0.5)
#plt.ylim(0.9, 1)
#plt.xlim(1.05, -0.05)
plt.legend()
plt.title("Fidelity Plot")
plt.savefig('diff_base_rates.jpg')
plt.show()
